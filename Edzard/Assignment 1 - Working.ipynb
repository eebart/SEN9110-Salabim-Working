# %% [markdown]
# # Airport Security Simulation

# %%
# Build a simulation model of airport that mimics:
# - Passport control (triangular 30-45-90 seconds)
# - Security scan (constant 10 seconds)
# Passengers arrive randomly (iat normal 60 seconds)
# Luggage on belt at security scan, one at a time (20-40 seconds)
# Conveyor 10m, speed 0.5 m/s
# At security scan manual check for 10% of passengers with one person, others don't wait 
# After luggage, passengers take luggage again (20-40 seconds)
# Passenger movements 2.5km/h, 10m along luggage belt
# Distance between other processes 5m ????

# Model for 4 hours, warm-up 1 hour.
# Run 10 replications (average + 90% confidence interval)
# Provide utilization data of passport control, scanner and secondary check

# %%
import salabim as sim

# %% [markdown]
# ## Working 15/09/2017

# %%
### Simulation without matching luggage to passenger

class PassengerGenerator(sim.Component):
    def process(self):
        while True:
            Passenger()
            yield self.hold(sim.Normal(60).sample())
            
class Passenger(sim.Component):
    def process(self):
        # Passport control
        self.enter(waitingline_passport)
        if passportcontrol.ispassive():
            passportcontrol.activate()
        yield self.passivate()
        
        # Walking from passport control to security scan
        yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
        
        # Security Scan
        self.enter(waitingline_security)
        if securityscan.ispassive():
            securityscan.activate()
        yield self.passivate()
        
        # Put luggage on belt
        yield self.hold(sim.Uniform(20,40).sample())
        Luggage(self.name())
        
        # 10% Pat Down Requirement
        if (sim.Uniform(1,100).sample() <= 10):
            # Walking from security scan to patdown
            yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
            # Patdown
            self.enter(waitingline_patdown)
            if patdown.ispassive():
                patdown.activate()
            yield self.passivate()
        
        # Walking along luggage belt
        yield self.hold(10/(0.5*1000/(60*60))) # convert 2.5 km/h to m/s
        
        # Pick up luggage, not matching owner
        yield self.hold(sim.Uniform(20,40).sample())
        waitingline_luggage.pop()
                
class Luggage(sim.Component): 
    def __init__(self, passengerName, *args, **kwargs): 
        super().__init__(*args, **kwargs)
        self.owner = passengerName
        
    def process(self):
        # Roll along luggage belt
        yield self.hold(10/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
        # Enter luggage waiting line
        self.enter(waitingline_luggage)
        
class PassportControl(sim.Component):
    def process(self):
        while True:
            while len(waitingline_passport) == 0:
                yield self.passivate()
            self.passenger = waitingline_passport.pop()
            yield self.hold(sim.Triangular(30.,90.,45.).sample())
            self.passenger.activate()
            
class SecurityScan(sim.Component):
    def process(self):
        while True:
            while len(waitingline_security) == 0:
                yield self.passivate()
            self.passenger = waitingline_security.pop()
            yield self.hold(10)
            self.passenger.activate()
            
class PatDown(sim.Component):
    def process(self):
        while True:
            while len(waitingline_patdown) == 0:
                yield self.passivate()
            self.passenger = waitingline_patdown.pop()
            yield self.hold(10) #TODO not yet defined
            self.passenger.activate()
            

env = sim.Environment(trace=True)

PassengerGenerator()
passportcontrol = PassportControl()
securityscan = SecurityScan()
patdown = PatDown()

waitingline_passport = sim.Queue('waitingline_passport')
waitingline_security = sim.Queue('waitingline_security')
waitingline_patdown = sim.Queue('waitingline_patdown')

waitingline_luggage = sim.Queue('waitingline_luggage')

env.run(till=60*60)
print()
waitingline_passport.print_statistics()
waitingline_security.print_statistics()
waitingline_patdown.print_statistics()
waitingline_luggage.print_statistics()
# Out:
#      0.000 main                 current
#                                 passengergenerator create
#                                 passengergenerator activate          scheduled for      0.000 @process
#                                 passportcontrol create
#                                 passportcontrol activate             scheduled for      0.000 @process
#                                 securityscan create
#                                 securityscan activate                scheduled for      0.000 @process
#                                 patdown create
#                                 patdown activate                     scheduled for      0.000 @process
#                                 waitingline_passport create
#                                 waitingline_security create
#                                 waitingline_patdown create
#                                 waitingline_luggage create
#                                 main run                             scheduled for   3600.000
#      0.000 passengergenerator   current
#                                 passenger create
#                                 passenger activate                   scheduled for      0.000 @process
#                                 passengergenerator hold              scheduled for     60.000
#      0.000 passportcontrol      current
#                                 passportcontrol passivate
#      0.000 securityscan         current
#                                 securityscan passivate
#      0.000 patdown              current
#                                 patdown passivate
#      0.000 passenger            current
#                                 passenger                            enter waitingline_passport
#                                 passportcontrol activate             scheduled for      0.000
#                                 passenger passivate
#      0.000 passportcontrol      current
#                                 passenger                            leave waitingline_passport
#                                 passportcontrol hold                 scheduled for     80.502
#     60.000 passengergenerator   current
#                                 passenger rename to passenger.0
#                                 passenger.1 create
#                                 passenger.1 activate                 scheduled for     60.000 @process
#                                 passengergenerator hold              scheduled for    120.000
#     60.000 passenger.1          current
#                                 passenger.1                          enter waitingline_passport
#                                 passenger.1 passivate
#     80.502 passportcontrol      current
#                                 passenger.0 activate                 scheduled for     80.502
#                                 passenger.1                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    135.040
#     80.502 passenger.0          current
#                                 passenger.0 hold                     scheduled for     87.702
#     87.702 passenger.0          current
#                                 passenger.0                          enter waitingline_security
#                                 securityscan activate                scheduled for     87.702
#                                 passenger.0 passivate
#     87.702 securityscan         current
#                                 passenger.0                          leave waitingline_security
#                                 securityscan hold                    scheduled for     97.702
#     97.702 securityscan         current
#                                 passenger.0 activate                 scheduled for     97.702
#                                 securityscan passivate
#     97.702 passenger.0          current
#                                 passenger.0 hold                     scheduled for    129.788
#    120.000 passengergenerator   current
#                                 passenger.2 create
#                                 passenger.2 activate                 scheduled for    120.000 @process
#                                 passengergenerator hold              scheduled for    180.000
#    120.000 passenger.2          current
#                                 passenger.2                          enter waitingline_passport
#                                 passenger.2 passivate
#    129.788 passenger.0          current
#                                 luggage create
#                                 luggage activate                     scheduled for    129.788 @process
#                                 passenger.0 hold                     scheduled for    201.788
#    129.788 luggage              current
#                                 luggage hold                         scheduled for    144.188
#    135.040 passportcontrol      current
#                                 passenger.1 activate                 scheduled for    135.040
#                                 passenger.2                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    180.182
#    135.040 passenger.1          current
#                                 passenger.1 hold                     scheduled for    142.240
#    142.240 passenger.1          current
#                                 passenger.1                          enter waitingline_security
#                                 securityscan activate                scheduled for    142.240
#                                 passenger.1 passivate
#    142.240 securityscan         current
#                                 passenger.1                          leave waitingline_security
#                                 securityscan hold                    scheduled for    152.240
#    144.188 luggage              current
#                                 luggage                              enter waitingline_luggage
#    144.188 luggage              ended
#    152.240 securityscan         current
#                                 passenger.1 activate                 scheduled for    152.240
#                                 securityscan passivate
#    152.240 passenger.1          current
#                                 passenger.1 hold                     scheduled for    179.156
#    179.156 passenger.1          current
#                                 luggage rename to luggage.0
#                                 luggage.1 create
#                                 luggage.1 activate                   scheduled for    179.156 @process
#                                 passenger.1 hold                     scheduled for    251.156
#    179.156 luggage.1            current
#                                 luggage.1 hold                       scheduled for    193.556
#    180.000 passengergenerator   current
#                                 passenger.3 create
#                                 passenger.3 activate                 scheduled for    180.000 @process
#                                 passengergenerator hold              scheduled for    240.000
#    180.000 passenger.3          current
#                                 passenger.3                          enter waitingline_passport
#                                 passenger.3 passivate
#    180.182 passportcontrol      current
#                                 passenger.2 activate                 scheduled for    180.182
#                                 passenger.3                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    242.073
#    180.182 passenger.2          current
#                                 passenger.2 hold                     scheduled for    187.382
#    187.382 passenger.2          current
#                                 passenger.2                          enter waitingline_security
#                                 securityscan activate                scheduled for    187.382
#                                 passenger.2 passivate
#    187.382 securityscan         current
#                                 passenger.2                          leave waitingline_security
#                                 securityscan hold                    scheduled for    197.382
#    193.556 luggage.1            current
#                                 luggage.1                            enter waitingline_luggage
#    193.556 luggage.1            ended
#    197.382 securityscan         current
#                                 passenger.2 activate                 scheduled for    197.382
#                                 securityscan passivate
#    197.382 passenger.2          current
#                                 passenger.2 hold                     scheduled for    225.447
#    201.788 passenger.0          current
#                                 passenger.0 hold                     scheduled for    232.869
#    225.447 passenger.2          current
#                                 luggage.2 create
#                                 luggage.2 activate                   scheduled for    225.447 @process
#                                 passenger.2 hold                     scheduled for    297.447
#    225.447 luggage.2            current
#                                 luggage.2 hold                       scheduled for    239.847
#    232.869 passenger.0          current
#                                 luggage.0                            leave waitingline_luggage
#    232.869 passenger.0          ended
#    239.847 luggage.2            current
#                                 luggage.2                            enter waitingline_luggage
#    239.847 luggage.2            ended
#    240.000 passengergenerator   current
#                                 passenger.4 create
#                                 passenger.4 activate                 scheduled for    240.000 @process
#                                 passengergenerator hold              scheduled for    300.000
#    240.000 passenger.4          current
#                                 passenger.4                          enter waitingline_passport
#                                 passenger.4 passivate
#    242.073 passportcontrol      current
#                                 passenger.3 activate                 scheduled for    242.073
#                                 passenger.4                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    295.339
#    242.073 passenger.3          current
#                                 passenger.3 hold                     scheduled for    249.273
#    249.273 passenger.3          current
#                                 passenger.3                          enter waitingline_security
#                                 securityscan activate                scheduled for    249.273
#                                 passenger.3 passivate
#    249.273 securityscan         current
#                                 passenger.3                          leave waitingline_security
#                                 securityscan hold                    scheduled for    259.273
#    251.156 passenger.1          current
#                                 passenger.1 hold                     scheduled for    281.224
#    259.273 securityscan         current
#                                 passenger.3 activate                 scheduled for    259.273
#                                 securityscan passivate
#    259.273 passenger.3          current
#                                 passenger.3 hold                     scheduled for    295.694
#    281.224 passenger.1          current
#                                 luggage.1                            leave waitingline_luggage
#    281.224 passenger.1          ended
#    295.339 passportcontrol      current
#                                 passenger.4 activate                 scheduled for    295.339
#                                 passportcontrol passivate
#    295.339 passenger.4          current
#                                 passenger.4 hold                     scheduled for    302.539
#    295.694 passenger.3          current
#                                 luggage.3 create
#                                 luggage.3 activate                   scheduled for    295.694 @process
#                                 passenger.3 hold                     scheduled for    367.694
#    295.694 luggage.3            current
#                                 luggage.3 hold                       scheduled for    310.094
#    297.447 passenger.2          current
#                                 passenger.2 hold                     scheduled for    334.809
#    300.000 passengergenerator   current
#                                 passenger.5 create
#                                 passenger.5 activate                 scheduled for    300.000 @process
#                                 passengergenerator hold              scheduled for    360.000
#    300.000 passenger.5          current
#                                 passenger.5                          enter waitingline_passport
#                                 passportcontrol activate             scheduled for    300.000
#                                 passenger.5 passivate
#    300.000 passportcontrol      current
#                                 passenger.5                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    352.284
#    302.539 passenger.4          current
#                                 passenger.4                          enter waitingline_security
#                                 securityscan activate                scheduled for    302.539
#                                 passenger.4 passivate
#    302.539 securityscan         current
#                                 passenger.4                          leave waitingline_security
#                                 securityscan hold                    scheduled for    312.539
#    310.094 luggage.3            current
#                                 luggage.3                            enter waitingline_luggage
#    310.094 luggage.3            ended
#    312.539 securityscan         current
#                                 passenger.4 activate                 scheduled for    312.539
#                                 securityscan passivate
#    312.539 passenger.4          current
#                                 passenger.4 hold                     scheduled for    336.347
#    334.809 passenger.2          current
#                                 luggage.2                            leave waitingline_luggage
#    334.809 passenger.2          ended
#    336.347 passenger.4          current
#                                 luggage.4 create
#                                 luggage.4 activate                   scheduled for    336.347 @process
#                                 passenger.4 hold                     scheduled for    408.347
#    336.347 luggage.4            current
#                                 luggage.4 hold                       scheduled for    350.747
#    350.747 luggage.4            current
#                                 luggage.4                            enter waitingline_luggage
#    350.747 luggage.4            ended
#    352.284 passportcontrol      current
#                                 passenger.5 activate                 scheduled for    352.284
#                                 passportcontrol passivate
#    352.284 passenger.5          current
#                                 passenger.5 hold                     scheduled for    359.484
#    359.484 passenger.5          current
#                                 passenger.5                          enter waitingline_security
#                                 securityscan activate                scheduled for    359.484
#                                 passenger.5 passivate
#    359.484 securityscan         current
#                                 passenger.5                          leave waitingline_security
#                                 securityscan hold                    scheduled for    369.484
#    360.000 passengergenerator   current
#                                 passenger.6 create
#                                 passenger.6 activate                 scheduled for    360.000 @process
#                                 passengergenerator hold              scheduled for    420.000
#    360.000 passenger.6          current
#                                 passenger.6                          enter waitingline_passport
#                                 passportcontrol activate             scheduled for    360.000
#                                 passenger.6 passivate
#    360.000 passportcontrol      current
#                                 passenger.6                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    402.197
#    367.694 passenger.3          current
#                                 passenger.3 hold                     scheduled for    396.696
#    369.484 securityscan         current
#                                 passenger.5 activate                 scheduled for    369.484
#                                 securityscan passivate
#    369.484 passenger.5          current
#                                 passenger.5 hold                     scheduled for    390.270
#    390.270 passenger.5          current
#                                 luggage.5 create
#                                 luggage.5 activate                   scheduled for    390.270 @process
#                                 passenger.5 hold                     scheduled for    462.270
#    390.270 luggage.5            current
#                                 luggage.5 hold                       scheduled for    404.670
#    396.696 passenger.3          current
#                                 luggage.3                            leave waitingline_luggage
#    396.696 passenger.3          ended
#    402.197 passportcontrol      current
#                                 passenger.6 activate                 scheduled for    402.197
#                                 passportcontrol passivate
#    402.197 passenger.6          current
#                                 passenger.6 hold                     scheduled for    409.397
#    404.670 luggage.5            current
#                                 luggage.5                            enter waitingline_luggage
#    404.670 luggage.5            ended
#    408.347 passenger.4          current
#                                 passenger.4 hold                     scheduled for    444.699
#    409.397 passenger.6          current
#                                 passenger.6                          enter waitingline_security
#                                 securityscan activate                scheduled for    409.397
#                                 passenger.6 passivate
#    409.397 securityscan         current
#                                 passenger.6                          leave waitingline_security
#                                 securityscan hold                    scheduled for    419.397
#    419.397 securityscan         current
#                                 passenger.6 activate                 scheduled for    419.397
#                                 securityscan passivate
#    419.397 passenger.6          current
#                                 passenger.6 hold                     scheduled for    449.499
#    420.000 passengergenerator   current
#                                 passenger.7 create
#                                 passenger.7 activate                 scheduled for    420.000 @process
#                                 passengergenerator hold              scheduled for    480.000
#    420.000 passenger.7          current
#                                 passenger.7                          enter waitingline_passport
#                                 passportcontrol activate             scheduled for    420.000
#                                 passenger.7 passivate
#    420.000 passportcontrol      current
#                                 passenger.7                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    454.222
#    444.699 passenger.4          current
#                                 luggage.4                            leave waitingline_luggage
#    444.699 passenger.4          ended
#    449.499 passenger.6          current
#                                 luggage.6 create
#                                 luggage.6 activate                   scheduled for    449.499 @process
#                                 passenger.6 hold                     scheduled for    456.699
#    449.499 luggage.6            current
#                                 luggage.6 hold                       scheduled for    463.899
#    454.222 passportcontrol      current
#                                 passenger.7 activate                 scheduled for    454.222
#                                 passportcontrol passivate
#    454.222 passenger.7          current
#                                 passenger.7 hold                     scheduled for    461.422
#    456.699 passenger.6          current
#                                 passenger.6                          enter waitingline_patdown
#                                 patdown activate                     scheduled for    456.699
#                                 passenger.6 passivate
#    456.699 patdown              current
#                                 passenger.6                          leave waitingline_patdown
#                                 patdown hold                         scheduled for    466.699
#    461.422 passenger.7          current
#                                 passenger.7                          enter waitingline_security
#                                 securityscan activate                scheduled for    461.422
#                                 passenger.7 passivate
#    461.422 securityscan         current
#                                 passenger.7                          leave waitingline_security
#                                 securityscan hold                    scheduled for    471.422
#    462.270 passenger.5          current
#                                 passenger.5 hold                     scheduled for    485.953
#    463.899 luggage.6            current
#                                 luggage.6                            enter waitingline_luggage
#    463.899 luggage.6            ended
#    466.699 patdown              current
#                                 passenger.6 activate                 scheduled for    466.699
#                                 patdown passivate
#    466.699 passenger.6          current
#                                 passenger.6 hold                     scheduled for    538.699
#    471.422 securityscan         current
#                                 passenger.7 activate                 scheduled for    471.422
#                                 securityscan passivate
#    471.422 passenger.7          current
#                                 passenger.7 hold                     scheduled for    508.573
#    480.000 passengergenerator   current
#                                 passenger.8 create
#                                 passenger.8 activate                 scheduled for    480.000 @process
#                                 passengergenerator hold              scheduled for    540.000
#    480.000 passenger.8          current
#                                 passenger.8                          enter waitingline_passport
#                                 passportcontrol activate             scheduled for    480.000
#                                 passenger.8 passivate
#    480.000 passportcontrol      current
#                                 passenger.8                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    517.641
#    485.953 passenger.5          current
#                                 luggage.5                            leave waitingline_luggage
#    485.953 passenger.5          ended
#    508.573 passenger.7          current
#                                 luggage.7 create
#                                 luggage.7 activate                   scheduled for    508.573 @process
#                                 passenger.7 hold                     scheduled for    580.573
#    508.573 luggage.7            current
#                                 luggage.7 hold                       scheduled for    522.973
#    517.641 passportcontrol      current
#                                 passenger.8 activate                 scheduled for    517.641
#                                 passportcontrol passivate
#    517.641 passenger.8          current
#                                 passenger.8 hold                     scheduled for    524.841
#    522.973 luggage.7            current
#                                 luggage.7                            enter waitingline_luggage
#    522.973 luggage.7            ended
#    524.841 passenger.8          current
#                                 passenger.8                          enter waitingline_security
#                                 securityscan activate                scheduled for    524.841
#                                 passenger.8 passivate
#    524.841 securityscan         current
#                                 passenger.8                          leave waitingline_security
#                                 securityscan hold                    scheduled for    534.841
#    534.841 securityscan         current
#                                 passenger.8 activate                 scheduled for    534.841
#                                 securityscan passivate
#    534.841 passenger.8          current
#                                 passenger.8 hold                     scheduled for    556.542
#    538.699 passenger.6          current
#                                 passenger.6 hold                     scheduled for    559.060
#    540.000 passengergenerator   current
#                                 passenger.9 create
#                                 passenger.9 activate                 scheduled for    540.000 @process
#                                 passengergenerator hold              scheduled for    600.000
#    540.000 passenger.9          current
#                                 passenger.9                          enter waitingline_passport
#                                 passportcontrol activate             scheduled for    540.000
#                                 passenger.9 passivate
#    540.000 passportcontrol      current
#                                 passenger.9                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    591.904
#    556.542 passenger.8          current
#                                 luggage.8 create
#                                 luggage.8 activate                   scheduled for    556.542 @process
#                                 passenger.8 hold                     scheduled for    628.542
#    556.542 luggage.8            current
#                                 luggage.8 hold                       scheduled for    570.942
#    559.060 passenger.6          current
#                                 luggage.6                            leave waitingline_luggage
#    559.060 passenger.6          ended
#    570.942 luggage.8            current
#                                 luggage.8                            enter waitingline_luggage
#    570.942 luggage.8            ended
#    580.573 passenger.7          current
#                                 passenger.7 hold                     scheduled for    619.261
#    591.904 passportcontrol      current
#                                 passenger.9 activate                 scheduled for    591.904
#                                 passportcontrol passivate
#    591.904 passenger.9          current
#                                 passenger.9 hold                     scheduled for    599.104
#    599.104 passenger.9          current
#                                 passenger.9                          enter waitingline_security
#                                 securityscan activate                scheduled for    599.104
#                                 passenger.9 passivate
#    599.104 securityscan         current
#                                 passenger.9                          leave waitingline_security
#                                 securityscan hold                    scheduled for    609.104
#    600.000 passengergenerator   current
#                                 passenger.10 create
#                                 passenger.10 activate                scheduled for    600.000 @process
#                                 passengergenerator hold              scheduled for    660.000
#    600.000 passenger.10         current
#                                 passenger.10                         enter waitingline_passport
#                                 passportcontrol activate             scheduled for    600.000
#                                 passenger.10 passivate
#    600.000 passportcontrol      current
#                                 passenger.10                         leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    650.200
#    609.104 securityscan         current
#                                 passenger.9 activate                 scheduled for    609.104
#                                 securityscan passivate
#    609.104 passenger.9          current
#                                 passenger.9 hold                     scheduled for    642.552
#    619.261 passenger.7          current
#                                 luggage.7                            leave waitingline_luggage
#    619.261 passenger.7          ended
#    628.542 passenger.8          current
#                                 passenger.8 hold                     scheduled for    648.589
#    642.552 passenger.9          current
#                                 luggage.9 create
#                                 luggage.9 activate                   scheduled for    642.552 @process
#                                 passenger.9 hold                     scheduled for    714.552
#    642.552 luggage.9            current
#                                 luggage.9 hold                       scheduled for    656.952
#    648.589 passenger.8          current
#                                 luggage.8                            leave waitingline_luggage
#    648.589 passenger.8          ended
#    650.200 passportcontrol      current
#                                 passenger.10 activate                scheduled for    650.200
#                                 passportcontrol passivate
#    650.200 passenger.10         current
#                                 passenger.10 hold                    scheduled for    657.400
#    656.952 luggage.9            current
#                                 luggage.9                            enter waitingline_luggage
#    656.952 luggage.9            ended
#    657.400 passenger.10         current
#                                 passenger.10                         enter waitingline_security
#                                 securityscan activate                scheduled for    657.400
#                                 passenger.10 passivate
#    657.400 securityscan         current
#                                 passenger.10                         leave waitingline_security
#                                 securityscan hold                    scheduled for    667.400
#    660.000 passengergenerator   current
#                                 passenger.11 create
#                                 passenger.11 activate                scheduled for    660.000 @process
#                                 passengergenerator hold              scheduled for    720.000
#    660.000 passenger.11         current
#                                 passenger.11                         enter waitingline_passport
#                                 passportcontrol activate             scheduled for    660.000
#                                 passenger.11 passivate
#    660.000 passportcontrol      current
#                                 passenger.11                         leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    719.274
#    667.400 securityscan         current
#                                 passenger.10 activate                scheduled for    667.400
#                                 securityscan passivate
#    667.400 passenger.10         current
#                                 passenger.10 hold                    scheduled for    706.046
#    706.046 passenger.10         current
#                                 luggage.10 create
#                                 luggage.10 activate                  scheduled for    706.046 @process
#                                 passenger.10 hold                    scheduled for    778.046
#    706.046 luggage.10           current
#                                 luggage.10 hold                      scheduled for    720.446
#    714.552 passenger.9          current
#                                 passenger.9 hold                     scheduled for    735.526
#    719.274 passportcontrol      current
#                                 passenger.11 activate                scheduled for    719.274
#                                 passportcontrol passivate
#    719.274 passenger.11         current
#                                 passenger.11 hold                    scheduled for    726.474
#    720.000 passengergenerator   current
#                                 passenger.12 create
#                                 passenger.12 activate                scheduled for    720.000 @process
#                                 passengergenerator hold              scheduled for    780.000
#    720.000 passenger.12         current
#                                 passenger.12                         enter waitingline_passport
#                                 passportcontrol activate             scheduled for    720.000
#                                 passenger.12 passivate
#    720.000 passportcontrol      current
#                                 passenger.12                         leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    782.690
#    720.446 luggage.10           current
#                                 luggage.10                           enter waitingline_luggage
#    720.446 luggage.10           ended
#    726.474 passenger.11         current
#                                 passenger.11                         enter waitingline_security
#                                 securityscan activate                scheduled for    726.474
#                                 passenger.11 passivate
#    726.474 securityscan         current
#                                 passenger.11                         leave waitingline_security
#                                 securityscan hold                    scheduled for    736.474
#    735.526 passenger.9          current
#                                 luggage.9                            leave waitingline_luggage
#    735.526 passenger.9          ended
#    736.474 securityscan         current
#                                 passenger.11 activate                scheduled for    736.474
#                                 securityscan passivate
#    736.474 passenger.11         current
#                                 passenger.11 hold                    scheduled for    762.575
#    762.575 passenger.11         current
#                                 luggage.11 create
#                                 luggage.11 activate                  scheduled for    762.575 @process
#                                 passenger.11 hold                    scheduled for    834.575
#    762.575 luggage.11           current
#                                 luggage.11 hold                      scheduled for    776.975
#    776.975 luggage.11           current
#                                 luggage.11                           enter waitingline_luggage
#    776.975 luggage.11           ended
#    778.046 passenger.10         current
#                                 passenger.10 hold                    scheduled for    809.998
#    780.000 passengergenerator   current
#                                 passenger.13 create
#                                 passenger.13 activate                scheduled for    780.000 @process
#                                 passengergenerator hold              scheduled for    840.000
#    780.000 passenger.13         current
#                                 passenger.13                         enter waitingline_passport
#                                 passenger.13 passivate
#    782.690 passportcontrol      current
#                                 passenger.12 activate                scheduled for    782.690
#                                 passenger.13                         leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    834.414
#    782.690 passenger.12         current
#                                 passenger.12 hold                    scheduled for    789.890
#    789.890 passenger.12         current
#                                 passenger.12                         enter waitingline_security
#                                 securityscan activate                scheduled for    789.890
#                                 passenger.12 passivate
#    789.890 securityscan         current
#                                 passenger.12                         leave waitingline_security
#                                 securityscan hold                    scheduled for    799.890
#    799.890 securityscan         current
#                                 passenger.12 activate                scheduled for    799.890
#                                 securityscan passivate
#    799.890 passenger.12         current
#                                 passenger.12 hold                    scheduled for    825.960
#    809.998 passenger.10         current
#                                 luggage.10                           leave waitingline_luggage
#    809.998 passenger.10         ended
#    825.960 passenger.12         current
#                                 luggage.12 create
#                                 luggage.12 activate                  scheduled for    825.960 @process
#                                 passenger.12 hold                    scheduled for    833.160
#    825.960 luggage.12           current
#                                 luggage.12 hold                      scheduled for    840.360
#    833.160 passenger.12         current
#                                 passenger.12                         enter waitingline_patdown
#                                 patdown activate                     scheduled for    833.160
#                                 passenger.12 passivate
#    833.160 patdown              current
#                                 passenger.12                         leave waitingline_patdown
#                                 patdown hold                         scheduled for    843.160
#    834.414 passportcontrol      current
#                                 passenger.13 activate                scheduled for    834.414
#                                 passportcontrol passivate
#    834.414 passenger.13         current
#                                 passenger.13 hold                    scheduled for    841.614
#    834.575 passenger.11         current
#                                 passenger.11 hold                    scheduled for    855.816
#    840.000 passengergenerator   current
#                                 passenger.14 create
#                                 passenger.14 activate                scheduled for    840.000 @process
#                                 passengergenerator hold              scheduled for    900.000
#    840.000 passenger.14         current
#                                 passenger.14                         enter waitingline_passport
#                                 passportcontrol activate             scheduled for    840.000
# ...
#                                 passengergenerator hold              scheduled for   3480.000
#   3420.000 passenger.57         current
#                                 passenger.57                         enter waitingline_passport
#                                 passportcontrol activate             scheduled for   3420.000
#                                 passenger.57 passivate
#   3420.000 passportcontrol      current
#                                 passenger.57                         leave waitingline_passport
#                                 passportcontrol hold                 scheduled for   3463.531
#   3420.788 luggage.55           current
#                                 luggage.55                           enter waitingline_luggage
#   3420.788 luggage.55           ended
#   3425.249 passenger.54         current
#                                 passenger.54 hold                    scheduled for   3452.360
#   3428.321 securityscan         current
#                                 passenger.56 activate                scheduled for   3428.321
#                                 securityscan passivate
#   3428.321 passenger.56         current
#                                 passenger.56 hold                    scheduled for   3454.747
#   3452.360 passenger.54         current
#                                 luggage.54                           leave waitingline_luggage
#   3452.360 passenger.54         ended
#   3454.747 passenger.56         current
#                                 luggage.56 create
#                                 luggage.56 activate                  scheduled for   3454.747 @process
#                                 passenger.56 hold                    scheduled for   3526.747
#   3454.747 luggage.56           current
#                                 luggage.56 hold                      scheduled for   3469.147
#   3463.531 passportcontrol      current
#                                 passenger.57 activate                scheduled for   3463.531
#                                 passportcontrol passivate
#   3463.531 passenger.57         current
#                                 passenger.57 hold                    scheduled for   3470.731
#   3469.147 luggage.56           current
#                                 luggage.56                           enter waitingline_luggage
#   3469.147 luggage.56           ended
#   3470.731 passenger.57         current
#                                 passenger.57                         enter waitingline_security
#                                 securityscan activate                scheduled for   3470.731
#                                 passenger.57 passivate
#   3470.731 securityscan         current
#                                 passenger.57                         leave waitingline_security
#                                 securityscan hold                    scheduled for   3480.731
#   3478.388 passenger.55         current
#                                 passenger.55 hold                    scheduled for   3511.208
#   3480.000 passengergenerator   current
#                                 passenger.58 create
#                                 passenger.58 activate                scheduled for   3480.000 @process
#                                 passengergenerator hold              scheduled for   3540.000
#   3480.000 passenger.58         current
#                                 passenger.58                         enter waitingline_passport
#                                 passportcontrol activate             scheduled for   3480.000
#                                 passenger.58 passivate
#   3480.000 passportcontrol      current
#                                 passenger.58                         leave waitingline_passport
#                                 passportcontrol hold                 scheduled for   3536.079
#   3480.731 securityscan         current
#                                 passenger.57 activate                scheduled for   3480.731
#                                 securityscan passivate
#   3480.731 passenger.57         current
#                                 passenger.57 hold                    scheduled for   3508.416
#   3508.416 passenger.57         current
#                                 luggage.57 create
#                                 luggage.57 activate                  scheduled for   3508.416 @process
#                                 passenger.57 hold                    scheduled for   3580.416
#   3508.416 luggage.57           current
#                                 luggage.57 hold                      scheduled for   3522.816
#   3511.208 passenger.55         current
#                                 luggage.55                           leave waitingline_luggage
#   3511.208 passenger.55         ended
#   3522.816 luggage.57           current
#                                 luggage.57                           enter waitingline_luggage
#   3522.816 luggage.57           ended
#   3526.747 passenger.56         current
#                                 passenger.56 hold                    scheduled for   3547.238
#   3536.079 passportcontrol      current
#                                 passenger.58 activate                scheduled for   3536.079
#                                 passportcontrol passivate
#   3536.079 passenger.58         current
#                                 passenger.58 hold                    scheduled for   3543.279
#   3540.000 passengergenerator   current
#                                 passenger.59 create
#                                 passenger.59 activate                scheduled for   3540.000 @process
#                                 passengergenerator hold              scheduled for   3600.000
#   3540.000 passenger.59         current
#                                 passenger.59                         enter waitingline_passport
#                                 passportcontrol activate             scheduled for   3540.000
#                                 passenger.59 passivate
#   3540.000 passportcontrol      current
#                                 passenger.59                         leave waitingline_passport
#                                 passportcontrol hold                 scheduled for   3619.187
#   3543.279 passenger.58         current
#                                 passenger.58                         enter waitingline_security
#                                 securityscan activate                scheduled for   3543.279
#                                 passenger.58 passivate
#   3543.279 securityscan         current
#                                 passenger.58                         leave waitingline_security
#                                 securityscan hold                    scheduled for   3553.279
#   3547.238 passenger.56         current
#                                 luggage.56                           leave waitingline_luggage
#   3547.238 passenger.56         ended
#   3553.279 securityscan         current
#                                 passenger.58 activate                scheduled for   3553.279
#                                 securityscan passivate
#   3553.279 passenger.58         current
#                                 passenger.58 hold                    scheduled for   3591.816
#   3580.416 passenger.57         current
#                                 passenger.57 hold                    scheduled for   3610.255
#   3591.816 passenger.58         current
#                                 luggage.58 create
#                                 luggage.58 activate                  scheduled for   3591.816 @process
#                                 passenger.58 hold                    scheduled for   3663.816
#   3591.816 luggage.58           current
#                                 luggage.58 hold                      scheduled for   3606.216
#   3600.000 main                 current
#
# Statistics of waitingline_passport at      3600.000
#                                                                      all    excl.zero         zero
# -------------------------------------------- -------------- ------------ ------------ ------------
# Length of waitingline_passport               duration           3600.000      465.513     3134.487
#                                              mean                  0.129        1.000
#                                              std.deviation         0.336        0.000
#
#                                              minimum               0.000        1.000
#                                              median                0.000        1.000
#                                              90% percentile        1.000        1.000
#                                              95% percentile        1.000        1.000
#                                              maximum               1.000        1.000
#
# Length of stay in waitingline_passport       entries                  60           32           28
#                                              mean                  7.759       14.547
#                                              std.deviation        10.419       10.237
#
#                                              minimum               0.000        0.182
#                                              median                2.158       13.367
#                                              90% percentile       22.919       25.493
#                                              95% percentile       25.842       32.715
#                                              maximum              41.614       41.614
# Statistics of waitingline_security at      3600.000
#                                                                      all    excl.zero         zero
# -------------------------------------------- -------------- ------------ ------------ ------------
# Length of waitingline_security               duration           3600.000        0.000     3600.000
#                                              mean                  0.000          nan
#                                              std.deviation         0.000          nan
#
#                                              minimum               0.000          nan
#                                              median                0.000          nan
#                                              90% percentile        0.000          nan
#                                              95% percentile        0.000          nan
#                                              maximum               0.000          nan
#
# Length of stay in waitingline_security       entries                  59            0           59
#                                              mean                  0.000          nan
#                                              std.deviation         0.000          nan
#
#                                              minimum               0.000          nan
#                                              median                0.000          nan
#                                              90% percentile        0.000          nan
#                                              95% percentile        0.000          nan
#                                              maximum               0.000          nan
# Statistics of waitingline_patdown at      3600.000
#                                                                      all    excl.zero         zero
# -------------------------------------------- -------------- ------------ ------------ ------------
# Length of waitingline_patdown                duration           3600.000        0.000     3600.000
#                                              mean                  0.000          nan
#                                              std.deviation         0.000          nan
#
#                                              minimum               0.000          nan
#                                              median                0.000          nan
#                                              90% percentile        0.000          nan
#                                              95% percentile        0.000          nan
#                                              maximum               0.000          nan
#
# Length of stay in waitingline_patdown        entries                   5            0            5
#                                              mean                  0.000          nan
#                                              std.deviation         0.000          nan
#
#                                              minimum               0.000          nan
#                                              median                0.000          nan
#                                              90% percentile        0.000          nan
#                                              95% percentile        0.000          nan
#                                              maximum               0.000          nan
# Statistics of waitingline_luggage at      3600.000
#                                                                      all    excl.zero         zero
# -------------------------------------------- -------------- ------------ ------------ ------------
# Length of waitingline_luggage                duration           3600.000     3424.487      175.513
#                                              mean                  1.409        1.482
#                                              std.deviation         0.605        0.527
#
#                                              minimum               0.000        1.000
#                                              median                1.000        1.000
#                                              90% percentile        2.000        2.000
#                                              95% percentile        2.000        2.000
#                                              maximum               3.000        3.000
#
# Length of stay in waitingline_luggage        entries                  57           57            0
#                                              mean                 87.661       87.661
#                                              std.deviation         8.369        8.369
#
#                                              minimum              77.617       77.617
#                                              median               86.602       86.602
#                                              90% percentile       95.612       95.612
#                                              95% percentile      104.636      104.636
#                                              maximum             113.828      113.828

# %%
### Simulation with matching luggage to passenger

class PassengerGenerator(sim.Component):
    def process(self):
        while True:
            Passenger()
            yield self.hold(sim.Normal(60).sample())
            
class Passenger(sim.Component):
    def process(self):
        # Passport control
        self.enter(waitingline_passport)
        if passportcontrol.ispassive():
            passportcontrol.activate()
        yield self.passivate()
        
        # Walking from passport control to security scan
        yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
        
        # Security Scan
        self.enter(waitingline_security)
        if securityscan.ispassive():
            securityscan.activate()
        yield self.passivate()
        
        # Put luggage on belt
        yield self.hold(sim.Uniform(20,40).sample())
        Luggage(self.name())
        
        # 10% Pat Down Requirement
        if (sim.Uniform(1,100).sample() <= 10):
            # Walking from security scan to patdown
            yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
            # Patdown
            self.enter(waitingline_patdown)
            if patdown.ispassive():
                patdown.activate()
            yield self.passivate()
        
        # Walking along luggage belt
        yield self.hold(10/(0.5*1000/(60*60))) # convert 2.5 km/h to m/s
        
        # Pick up luggage, not matching owner
        self.enter(waitingline_passengerLuggagePickup)
        if luggagePickup.ispassive():
            luggagePickup.activate()
        yield self.passivate()
                
class Luggage(sim.Component): 
    def __init__(self, passengerName, *args, **kwargs): 
        super().__init__(*args, **kwargs)
        self.owner = passengerName
        
    def process(self):
        # Roll along luggage belt
        yield self.hold(10/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
        
        # Enter luggage waiting line
        self.enter(waitingline_luggageLuggagePickup)
        if luggagePickup.ispassive():
                luggagePickup.activate()
        self.passivate()
        
class LuggagePickup(sim.Component):
    def process(self):
        while True:
            while len(waitingline_passengerLuggagePickup) == 0 or len(waitingline_luggageLuggagePickup) == 0:
                yield self.passivate()
            for passenger in waitingline_passengerLuggagePickup:
                  for luggage in waitingline_luggageLuggagePickup: 
                        if luggage.owner == passenger.name(): 
                            #found luggage of owner!
                            waitingline_passengerLuggagePickup.remove(passenger)
                            waitingline_luggageLuggagePickup.remove(luggage)
                            
                            yield self.hold(sim.Uniform(20,40).sample())

                            passenger.activate()
                            #luggage.activate()

                            break
        
class PassportControl(sim.Component):
    def process(self):
        while True:
            while len(waitingline_passport) == 0:
                yield self.passivate()
            self.passenger = waitingline_passport.pop()
            yield self.hold(sim.Triangular(30.,90.,45.).sample())
            self.passenger.activate()
            
class SecurityScan(sim.Component):
    def process(self):
        while True:
            while len(waitingline_security) == 0:
                yield self.passivate()
            self.passenger = waitingline_security.pop()
            yield self.hold(10)
            self.passenger.activate()
            
class PatDown(sim.Component):
    def process(self):
        while True:
            while len(waitingline_patdown) == 0:
                yield self.passivate()
            self.passenger = waitingline_patdown.pop()
            yield self.hold(10) #TODO not yet defined
            self.passenger.activate()
            

env = sim.Environment(trace=True)

PassengerGenerator()
passportcontrol = PassportControl()
securityscan = SecurityScan()
patdown = PatDown()
luggagePickup = LuggagePickup()

waitingline_passport = sim.Queue('waitingline_passport')
waitingline_security = sim.Queue('waitingline_security')
waitingline_patdown = sim.Queue('waitingline_patdown')

waitingline_luggageLuggagePickup = sim.Queue('waitingline_luggageLuggagePickup')
waitingline_passengerLuggagePickup = sim.Queue('waitingline_passengerLuggagePickup')

env.run(till=60*60)
print()
waitingline_passport.print_statistics()
waitingline_security.print_statistics()
waitingline_patdown.print_statistics()
waitingline_luggage.print_statistics()
# Out:
#      0.000 main                 current
#                                 passengergenerator create
#                                 passengergenerator activate          scheduled for      0.000 @process
#                                 passportcontrol create
#                                 passportcontrol activate             scheduled for      0.000 @process
#                                 securityscan create
#                                 securityscan activate                scheduled for      0.000 @process
#                                 patdown create
#                                 patdown activate                     scheduled for      0.000 @process
#                                 luggagepickup create
#                                 luggagepickup activate               scheduled for      0.000 @process
#                                 waitingline_passport create
#                                 waitingline_security create
#                                 waitingline_patdown create
#                                 waitingline_luggageLuggagePickup create
#                                 waitingline_passengerLuggagePickup create
#                                 main run                             scheduled for   3600.000
#      0.000 passengergenerator   current
#                                 passenger create
#                                 passenger activate                   scheduled for      0.000 @process
#                                 passengergenerator hold              scheduled for     60.000
#      0.000 passportcontrol      current
#                                 passportcontrol passivate
#      0.000 securityscan         current
#                                 securityscan passivate
#      0.000 patdown              current
#                                 patdown passivate
#      0.000 luggagepickup        current
#                                 luggagepickup passivate
#      0.000 passenger            current
#                                 passenger                            enter waitingline_passport
#                                 passportcontrol activate             scheduled for      0.000
#                                 passenger passivate
#      0.000 passportcontrol      current
#                                 passenger                            leave waitingline_passport
#                                 passportcontrol hold                 scheduled for     80.502
#     60.000 passengergenerator   current
#                                 passenger rename to passenger.0
#                                 passenger.1 create
#                                 passenger.1 activate                 scheduled for     60.000 @process
#                                 passengergenerator hold              scheduled for    120.000
#     60.000 passenger.1          current
#                                 passenger.1                          enter waitingline_passport
#                                 passenger.1 passivate
#     80.502 passportcontrol      current
#                                 passenger.0 activate                 scheduled for     80.502
#                                 passenger.1                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    135.040
#     80.502 passenger.0          current
#                                 passenger.0 hold                     scheduled for     87.702
#     87.702 passenger.0          current
#                                 passenger.0                          enter waitingline_security
#                                 securityscan activate                scheduled for     87.702
#                                 passenger.0 passivate
#     87.702 securityscan         current
#                                 passenger.0                          leave waitingline_security
#                                 securityscan hold                    scheduled for     97.702
#     97.702 securityscan         current
#                                 passenger.0 activate                 scheduled for     97.702
#                                 securityscan passivate
#     97.702 passenger.0          current
#                                 passenger.0 hold                     scheduled for    129.788
#    120.000 passengergenerator   current
#                                 passenger.2 create
#                                 passenger.2 activate                 scheduled for    120.000 @process
#                                 passengergenerator hold              scheduled for    180.000
#    120.000 passenger.2          current
#                                 passenger.2                          enter waitingline_passport
#                                 passenger.2 passivate
#    129.788 passenger.0          current
#                                 luggage create
#                                 luggage activate                     scheduled for    129.788 @process
#                                 passenger.0 hold                     scheduled for    201.788
#    129.788 luggage              current
#                                 luggage hold                         scheduled for    144.188
#    135.040 passportcontrol      current
#                                 passenger.1 activate                 scheduled for    135.040
#                                 passenger.2                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    180.182
#    135.040 passenger.1          current
#                                 passenger.1 hold                     scheduled for    142.240
#    142.240 passenger.1          current
#                                 passenger.1                          enter waitingline_security
#                                 securityscan activate                scheduled for    142.240
#                                 passenger.1 passivate
#    142.240 securityscan         current
#                                 passenger.1                          leave waitingline_security
#                                 securityscan hold                    scheduled for    152.240
#    144.188 luggage              current
#                                 luggage                              enter waitingline_luggageLuggagePickup
#                                 luggagepickup activate               scheduled for    144.188
#                                 luggage passivate
#    144.188 luggage              ended
#    144.188 luggagepickup        current
#                                 luggagepickup passivate
#    152.240 securityscan         current
#                                 passenger.1 activate                 scheduled for    152.240
#                                 securityscan passivate
#    152.240 passenger.1          current
#                                 passenger.1 hold                     scheduled for    179.156
#    179.156 passenger.1          current
#                                 luggage rename to luggage.0
#                                 luggage.1 create
#                                 luggage.1 activate                   scheduled for    179.156 @process
#                                 passenger.1 hold                     scheduled for    251.156
#    179.156 luggage.1            current
#                                 luggage.1 hold                       scheduled for    193.556
#    180.000 passengergenerator   current
#                                 passenger.3 create
#                                 passenger.3 activate                 scheduled for    180.000 @process
#                                 passengergenerator hold              scheduled for    240.000
#    180.000 passenger.3          current
#                                 passenger.3                          enter waitingline_passport
#                                 passenger.3 passivate
#    180.182 passportcontrol      current
#                                 passenger.2 activate                 scheduled for    180.182
#                                 passenger.3                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    242.073
#    180.182 passenger.2          current
#                                 passenger.2 hold                     scheduled for    187.382
#    187.382 passenger.2          current
#                                 passenger.2                          enter waitingline_security
#                                 securityscan activate                scheduled for    187.382
#                                 passenger.2 passivate
#    187.382 securityscan         current
#                                 passenger.2                          leave waitingline_security
#                                 securityscan hold                    scheduled for    197.382
#    193.556 luggage.1            current
#                                 luggage.1                            enter waitingline_luggageLuggagePickup
#                                 luggagepickup activate               scheduled for    193.556
#                                 luggage.1 passivate
#    193.556 luggage.1            ended
#    193.556 luggagepickup        current
#                                 luggagepickup passivate
#    197.382 securityscan         current
#                                 passenger.2 activate                 scheduled for    197.382
#                                 securityscan passivate
#    197.382 passenger.2          current
#                                 passenger.2 hold                     scheduled for    225.447
#    201.788 passenger.0          current
#                                 passenger.0                          enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for    201.788
#                                 passenger.0 passivate
#    201.788 luggagepickup        current
#                                 passenger.0                          leave waitingline_passengerLuggagePickup
#                                 luggage.0                            leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for    232.869
#    225.447 passenger.2          current
#                                 luggage.2 create
#                                 luggage.2 activate                   scheduled for    225.447 @process
#                                 passenger.2 hold                     scheduled for    297.447
#    225.447 luggage.2            current
#                                 luggage.2 hold                       scheduled for    239.847
#    232.869 luggagepickup        current
#                                 passenger.0 activate                 scheduled for    232.869
#                                 luggagepickup passivate
#    232.869 passenger.0          current
#    232.869 passenger.0          ended
#    239.847 luggage.2            current
#                                 luggage.2                            enter waitingline_luggageLuggagePickup
#                                 luggagepickup activate               scheduled for    239.847
#                                 luggage.2 passivate
#    239.847 luggage.2            ended
#    239.847 luggagepickup        current
#                                 luggagepickup passivate
#    240.000 passengergenerator   current
#                                 passenger.4 create
#                                 passenger.4 activate                 scheduled for    240.000 @process
#                                 passengergenerator hold              scheduled for    300.000
#    240.000 passenger.4          current
#                                 passenger.4                          enter waitingline_passport
#                                 passenger.4 passivate
#    242.073 passportcontrol      current
#                                 passenger.3 activate                 scheduled for    242.073
#                                 passenger.4                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    295.339
#    242.073 passenger.3          current
#                                 passenger.3 hold                     scheduled for    249.273
#    249.273 passenger.3          current
#                                 passenger.3                          enter waitingline_security
#                                 securityscan activate                scheduled for    249.273
#                                 passenger.3 passivate
#    249.273 securityscan         current
#                                 passenger.3                          leave waitingline_security
#                                 securityscan hold                    scheduled for    259.273
#    251.156 passenger.1          current
#                                 passenger.1                          enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for    251.156
#                                 passenger.1 passivate
#    251.156 luggagepickup        current
#                                 passenger.1                          leave waitingline_passengerLuggagePickup
#                                 luggage.1                            leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for    281.224
#    259.273 securityscan         current
#                                 passenger.3 activate                 scheduled for    259.273
#                                 securityscan passivate
#    259.273 passenger.3          current
#                                 passenger.3 hold                     scheduled for    295.694
#    281.224 luggagepickup        current
#                                 passenger.1 activate                 scheduled for    281.224
#                                 luggagepickup passivate
#    281.224 passenger.1          current
#    281.224 passenger.1          ended
#    295.339 passportcontrol      current
#                                 passenger.4 activate                 scheduled for    295.339
#                                 passportcontrol passivate
#    295.339 passenger.4          current
#                                 passenger.4 hold                     scheduled for    302.539
#    295.694 passenger.3          current
#                                 luggage.3 create
#                                 luggage.3 activate                   scheduled for    295.694 @process
#                                 passenger.3 hold                     scheduled for    367.694
#    295.694 luggage.3            current
#                                 luggage.3 hold                       scheduled for    310.094
#    297.447 passenger.2          current
#                                 passenger.2                          enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for    297.447
#                                 passenger.2 passivate
#    297.447 luggagepickup        current
#                                 passenger.2                          leave waitingline_passengerLuggagePickup
#                                 luggage.2                            leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for    334.809
#    300.000 passengergenerator   current
#                                 passenger.5 create
#                                 passenger.5 activate                 scheduled for    300.000 @process
#                                 passengergenerator hold              scheduled for    360.000
#    300.000 passenger.5          current
#                                 passenger.5                          enter waitingline_passport
#                                 passportcontrol activate             scheduled for    300.000
#                                 passenger.5 passivate
#    300.000 passportcontrol      current
#                                 passenger.5                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    352.284
#    302.539 passenger.4          current
#                                 passenger.4                          enter waitingline_security
#                                 securityscan activate                scheduled for    302.539
#                                 passenger.4 passivate
#    302.539 securityscan         current
#                                 passenger.4                          leave waitingline_security
#                                 securityscan hold                    scheduled for    312.539
#    310.094 luggage.3            current
#                                 luggage.3                            enter waitingline_luggageLuggagePickup
#                                 luggage.3 passivate
#    310.094 luggage.3            ended
#    312.539 securityscan         current
#                                 passenger.4 activate                 scheduled for    312.539
#                                 securityscan passivate
#    312.539 passenger.4          current
#                                 passenger.4 hold                     scheduled for    336.347
#    334.809 luggagepickup        current
#                                 passenger.2 activate                 scheduled for    334.809
#                                 luggagepickup passivate
#    334.809 passenger.2          current
#    334.809 passenger.2          ended
#    336.347 passenger.4          current
#                                 luggage.4 create
#                                 luggage.4 activate                   scheduled for    336.347 @process
#                                 passenger.4 hold                     scheduled for    408.347
#    336.347 luggage.4            current
#                                 luggage.4 hold                       scheduled for    350.747
#    350.747 luggage.4            current
#                                 luggage.4                            enter waitingline_luggageLuggagePickup
#                                 luggagepickup activate               scheduled for    350.747
#                                 luggage.4 passivate
#    350.747 luggage.4            ended
#    350.747 luggagepickup        current
#                                 luggagepickup passivate
#    352.284 passportcontrol      current
#                                 passenger.5 activate                 scheduled for    352.284
#                                 passportcontrol passivate
#    352.284 passenger.5          current
#                                 passenger.5 hold                     scheduled for    359.484
#    359.484 passenger.5          current
#                                 passenger.5                          enter waitingline_security
#                                 securityscan activate                scheduled for    359.484
#                                 passenger.5 passivate
#    359.484 securityscan         current
#                                 passenger.5                          leave waitingline_security
#                                 securityscan hold                    scheduled for    369.484
#    360.000 passengergenerator   current
#                                 passenger.6 create
#                                 passenger.6 activate                 scheduled for    360.000 @process
#                                 passengergenerator hold              scheduled for    420.000
#    360.000 passenger.6          current
#                                 passenger.6                          enter waitingline_passport
#                                 passportcontrol activate             scheduled for    360.000
#                                 passenger.6 passivate
#    360.000 passportcontrol      current
#                                 passenger.6                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    402.197
#    367.694 passenger.3          current
#                                 passenger.3                          enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for    367.694
#                                 passenger.3 passivate
#    367.694 luggagepickup        current
#                                 passenger.3                          leave waitingline_passengerLuggagePickup
#                                 luggage.3                            leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for    396.696
#    369.484 securityscan         current
#                                 passenger.5 activate                 scheduled for    369.484
#                                 securityscan passivate
#    369.484 passenger.5          current
#                                 passenger.5 hold                     scheduled for    390.270
#    390.270 passenger.5          current
#                                 luggage.5 create
#                                 luggage.5 activate                   scheduled for    390.270 @process
#                                 passenger.5 hold                     scheduled for    462.270
#    390.270 luggage.5            current
#                                 luggage.5 hold                       scheduled for    404.670
#    396.696 luggagepickup        current
#                                 passenger.3 activate                 scheduled for    396.696
#                                 luggagepickup passivate
#    396.696 passenger.3          current
#    396.696 passenger.3          ended
#    402.197 passportcontrol      current
#                                 passenger.6 activate                 scheduled for    402.197
#                                 passportcontrol passivate
#    402.197 passenger.6          current
#                                 passenger.6 hold                     scheduled for    409.397
#    404.670 luggage.5            current
#                                 luggage.5                            enter waitingline_luggageLuggagePickup
#                                 luggagepickup activate               scheduled for    404.670
#                                 luggage.5 passivate
#    404.670 luggage.5            ended
#    404.670 luggagepickup        current
#                                 luggagepickup passivate
#    408.347 passenger.4          current
#                                 passenger.4                          enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for    408.347
#                                 passenger.4 passivate
#    408.347 luggagepickup        current
#                                 passenger.4                          leave waitingline_passengerLuggagePickup
#                                 luggage.4                            leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for    444.699
#    409.397 passenger.6          current
#                                 passenger.6                          enter waitingline_security
#                                 securityscan activate                scheduled for    409.397
#                                 passenger.6 passivate
#    409.397 securityscan         current
#                                 passenger.6                          leave waitingline_security
#                                 securityscan hold                    scheduled for    419.397
#    419.397 securityscan         current
#                                 passenger.6 activate                 scheduled for    419.397
#                                 securityscan passivate
#    419.397 passenger.6          current
#                                 passenger.6 hold                     scheduled for    449.499
#    420.000 passengergenerator   current
#                                 passenger.7 create
#                                 passenger.7 activate                 scheduled for    420.000 @process
#                                 passengergenerator hold              scheduled for    480.000
#    420.000 passenger.7          current
#                                 passenger.7                          enter waitingline_passport
#                                 passportcontrol activate             scheduled for    420.000
#                                 passenger.7 passivate
#    420.000 passportcontrol      current
#                                 passenger.7                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    454.222
#    444.699 luggagepickup        current
#                                 passenger.4 activate                 scheduled for    444.699
#                                 luggagepickup passivate
#    444.699 passenger.4          current
#    444.699 passenger.4          ended
#    449.499 passenger.6          current
#                                 luggage.6 create
#                                 luggage.6 activate                   scheduled for    449.499 @process
#                                 passenger.6 hold                     scheduled for    456.699
#    449.499 luggage.6            current
#                                 luggage.6 hold                       scheduled for    463.899
#    454.222 passportcontrol      current
#                                 passenger.7 activate                 scheduled for    454.222
#                                 passportcontrol passivate
#    454.222 passenger.7          current
#                                 passenger.7 hold                     scheduled for    461.422
#    456.699 passenger.6          current
#                                 passenger.6                          enter waitingline_patdown
#                                 patdown activate                     scheduled for    456.699
#                                 passenger.6 passivate
#    456.699 patdown              current
#                                 passenger.6                          leave waitingline_patdown
#                                 patdown hold                         scheduled for    466.699
#    461.422 passenger.7          current
#                                 passenger.7                          enter waitingline_security
#                                 securityscan activate                scheduled for    461.422
#                                 passenger.7 passivate
#    461.422 securityscan         current
#                                 passenger.7                          leave waitingline_security
#                                 securityscan hold                    scheduled for    471.422
#    462.270 passenger.5          current
#                                 passenger.5                          enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for    462.270
#                                 passenger.5 passivate
#    462.270 luggagepickup        current
#                                 passenger.5                          leave waitingline_passengerLuggagePickup
#                                 luggage.5                            leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for    485.953
#    463.899 luggage.6            current
#                                 luggage.6                            enter waitingline_luggageLuggagePickup
#                                 luggage.6 passivate
#    463.899 luggage.6            ended
#    466.699 patdown              current
#                                 passenger.6 activate                 scheduled for    466.699
#                                 patdown passivate
#    466.699 passenger.6          current
#                                 passenger.6 hold                     scheduled for    538.699
#    471.422 securityscan         current
#                                 passenger.7 activate                 scheduled for    471.422
#                                 securityscan passivate
#    471.422 passenger.7          current
#                                 passenger.7 hold                     scheduled for    508.573
#    480.000 passengergenerator   current
#                                 passenger.8 create
#                                 passenger.8 activate                 scheduled for    480.000 @process
#                                 passengergenerator hold              scheduled for    540.000
#    480.000 passenger.8          current
#                                 passenger.8                          enter waitingline_passport
#                                 passportcontrol activate             scheduled for    480.000
#                                 passenger.8 passivate
#    480.000 passportcontrol      current
#                                 passenger.8                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    517.641
#    485.953 luggagepickup        current
#                                 passenger.5 activate                 scheduled for    485.953
#                                 luggagepickup passivate
#    485.953 passenger.5          current
#    485.953 passenger.5          ended
#    508.573 passenger.7          current
#                                 luggage.7 create
#                                 luggage.7 activate                   scheduled for    508.573 @process
#                                 passenger.7 hold                     scheduled for    580.573
#    508.573 luggage.7            current
#                                 luggage.7 hold                       scheduled for    522.973
#    517.641 passportcontrol      current
#                                 passenger.8 activate                 scheduled for    517.641
#                                 passportcontrol passivate
#    517.641 passenger.8          current
#                                 passenger.8 hold                     scheduled for    524.841
#    522.973 luggage.7            current
#                                 luggage.7                            enter waitingline_luggageLuggagePickup
#                                 luggagepickup activate               scheduled for    522.973
#                                 luggage.7 passivate
#    522.973 luggage.7            ended
#    522.973 luggagepickup        current
#                                 luggagepickup passivate
#    524.841 passenger.8          current
#                                 passenger.8                          enter waitingline_security
#                                 securityscan activate                scheduled for    524.841
#                                 passenger.8 passivate
#    524.841 securityscan         current
#                                 passenger.8                          leave waitingline_security
#                                 securityscan hold                    scheduled for    534.841
#    534.841 securityscan         current
#                                 passenger.8 activate                 scheduled for    534.841
#                                 securityscan passivate
#    534.841 passenger.8          current
#                                 passenger.8 hold                     scheduled for    556.542
#    538.699 passenger.6          current
#                                 passenger.6                          enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for    538.699
#                                 passenger.6 passivate
#    538.699 luggagepickup        current
#                                 passenger.6                          leave waitingline_passengerLuggagePickup
#                                 luggage.6                            leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for    559.060
#    540.000 passengergenerator   current
#                                 passenger.9 create
#                                 passenger.9 activate                 scheduled for    540.000 @process
#                                 passengergenerator hold              scheduled for    600.000
#    540.000 passenger.9          current
#                                 passenger.9                          enter waitingline_passport
#                                 passportcontrol activate             scheduled for    540.000
#                                 passenger.9 passivate
#    540.000 passportcontrol      current
#                                 passenger.9                          leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    591.904
#    556.542 passenger.8          current
#                                 luggage.8 create
#                                 luggage.8 activate                   scheduled for    556.542 @process
#                                 passenger.8 hold                     scheduled for    628.542
#    556.542 luggage.8            current
#                                 luggage.8 hold                       scheduled for    570.942
#    559.060 luggagepickup        current
#                                 passenger.6 activate                 scheduled for    559.060
#                                 luggagepickup passivate
#    559.060 passenger.6          current
#    559.060 passenger.6          ended
#    570.942 luggage.8            current
#                                 luggage.8                            enter waitingline_luggageLuggagePickup
#                                 luggagepickup activate               scheduled for    570.942
#                                 luggage.8 passivate
#    570.942 luggage.8            ended
#    570.942 luggagepickup        current
#                                 luggagepickup passivate
#    580.573 passenger.7          current
#                                 passenger.7                          enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for    580.573
#                                 passenger.7 passivate
#    580.573 luggagepickup        current
#                                 passenger.7                          leave waitingline_passengerLuggagePickup
#                                 luggage.7                            leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for    619.261
#    591.904 passportcontrol      current
#                                 passenger.9 activate                 scheduled for    591.904
#                                 passportcontrol passivate
#    591.904 passenger.9          current
#                                 passenger.9 hold                     scheduled for    599.104
#    599.104 passenger.9          current
#                                 passenger.9                          enter waitingline_security
#                                 securityscan activate                scheduled for    599.104
#                                 passenger.9 passivate
#    599.104 securityscan         current
#                                 passenger.9                          leave waitingline_security
#                                 securityscan hold                    scheduled for    609.104
#    600.000 passengergenerator   current
#                                 passenger.10 create
#                                 passenger.10 activate                scheduled for    600.000 @process
#                                 passengergenerator hold              scheduled for    660.000
#    600.000 passenger.10         current
#                                 passenger.10                         enter waitingline_passport
#                                 passportcontrol activate             scheduled for    600.000
#                                 passenger.10 passivate
#    600.000 passportcontrol      current
#                                 passenger.10                         leave waitingline_passport
#                                 passportcontrol hold                 scheduled for    650.200
#    609.104 securityscan         current
#                                 passenger.9 activate                 scheduled for    609.104
#                                 securityscan passivate
#    609.104 passenger.9          current
#                                 passenger.9 hold                     scheduled for    642.552
#    619.261 luggagepickup        current
#                                 passenger.7 activate                 scheduled for    619.261
#                                 luggagepickup passivate
#    619.261 passenger.7          current
#    619.261 passenger.7          ended
#    628.542 passenger.8          current
#                                 passenger.8                          enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for    628.542
#                                 passenger.8 passivate
#    628.542 luggagepickup        current
#                                 passenger.8                          leave waitingline_passengerLuggagePickup
#                                 luggage.8                            leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for    648.589
#    642.552 passenger.9          current
#                                 luggage.9 create
#                                 luggage.9 activate                   scheduled for    642.552 @process
#                                 passenger.9 hold                     scheduled for    714.552
#    642.552 luggage.9            current
#                                 luggage.9 hold                       scheduled for    656.952
#    648.589 luggagepickup        current
#                                 passenger.8 activate                 scheduled for    648.589
#                                 luggagepickup passivate
#    648.589 passenger.8          current
#    648.589 passenger.8          ended
#    650.200 passportcontrol      current
#                                 passenger.10 activate                scheduled for    650.200
#                                 passportcontrol passivate
#    650.200 passenger.10         current
#                                 passenger.10 hold                    scheduled for    657.400
#    656.952 luggage.9            current
#                                 luggage.9                            enter waitingline_luggageLuggagePickup
#                                 luggagepickup activate               scheduled for    656.952
#                                 luggage.9 passivate
#    656.952 luggage.9            ended
#    656.952 luggagepickup        current
#                                 luggagepickup passivate
#    657.400 passenger.10         current
#                                 passenger.10                         enter waitingline_security
#                                 securityscan activate                scheduled for    657.400
#                                 passenger.10 passivate
#    657.400 securityscan         current
#                                 passenger.10                         leave waitingline_security
#                                 securityscan hold                    scheduled for    667.400
#    660.000 passengergenerator   current
#                                 passenger.11 create
#                                 passenger.11 activate                scheduled for    660.000 @process
#                                 passengergenerator hold              scheduled for    720.000
#    660.000 passenger.11         current
#                                 passenger.11                         enter waitingline_passport
#                                 passportcontrol activate             scheduled for    660.000
#                                 passenger.11 passivate
#    660.000 passportcontrol      current
#                                 passenger.11                         leave waitingline_passport
# ...
#   3469.147 luggage.56           current
#                                 luggage.56                           enter waitingline_luggageLuggagePickup
#                                 luggagepickup activate               scheduled for   3469.147
#                                 luggage.56 passivate
#   3469.147 luggage.56           ended
#   3469.147 luggagepickup        current
#                                 luggagepickup passivate
#   3470.731 passenger.57         current
#                                 passenger.57                         enter waitingline_security
#                                 securityscan activate                scheduled for   3470.731
#                                 passenger.57 passivate
#   3470.731 securityscan         current
#                                 passenger.57                         leave waitingline_security
#                                 securityscan hold                    scheduled for   3480.731
#   3478.388 passenger.55         current
#                                 passenger.55                         enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for   3478.388
#                                 passenger.55 passivate
#   3478.388 luggagepickup        current
#                                 passenger.55                         leave waitingline_passengerLuggagePickup
#                                 luggage.55                           leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for   3511.208
#   3480.000 passengergenerator   current
#                                 passenger.58 create
#                                 passenger.58 activate                scheduled for   3480.000 @process
#                                 passengergenerator hold              scheduled for   3540.000
#   3480.000 passenger.58         current
#                                 passenger.58                         enter waitingline_passport
#                                 passportcontrol activate             scheduled for   3480.000
#                                 passenger.58 passivate
#   3480.000 passportcontrol      current
#                                 passenger.58                         leave waitingline_passport
#                                 passportcontrol hold                 scheduled for   3536.079
#   3480.731 securityscan         current
#                                 passenger.57 activate                scheduled for   3480.731
#                                 securityscan passivate
#   3480.731 passenger.57         current
#                                 passenger.57 hold                    scheduled for   3508.416
#   3508.416 passenger.57         current
#                                 luggage.57 create
#                                 luggage.57 activate                  scheduled for   3508.416 @process
#                                 passenger.57 hold                    scheduled for   3580.416
#   3508.416 luggage.57           current
#                                 luggage.57 hold                      scheduled for   3522.816
#   3511.208 luggagepickup        current
#                                 passenger.55 activate                scheduled for   3511.208
#                                 luggagepickup passivate
#   3511.208 passenger.55         current
#   3511.208 passenger.55         ended
#   3522.816 luggage.57           current
#                                 luggage.57                           enter waitingline_luggageLuggagePickup
#                                 luggagepickup activate               scheduled for   3522.816
#                                 luggage.57 passivate
#   3522.816 luggage.57           ended
#   3522.816 luggagepickup        current
#                                 luggagepickup passivate
#   3526.747 passenger.56         current
#                                 passenger.56                         enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for   3526.747
#                                 passenger.56 passivate
#   3526.747 luggagepickup        current
#                                 passenger.56                         leave waitingline_passengerLuggagePickup
#                                 luggage.56                           leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for   3547.238
#   3536.079 passportcontrol      current
#                                 passenger.58 activate                scheduled for   3536.079
#                                 passportcontrol passivate
#   3536.079 passenger.58         current
#                                 passenger.58 hold                    scheduled for   3543.279
#   3540.000 passengergenerator   current
#                                 passenger.59 create
#                                 passenger.59 activate                scheduled for   3540.000 @process
#                                 passengergenerator hold              scheduled for   3600.000
#   3540.000 passenger.59         current
#                                 passenger.59                         enter waitingline_passport
#                                 passportcontrol activate             scheduled for   3540.000
#                                 passenger.59 passivate
#   3540.000 passportcontrol      current
#                                 passenger.59                         leave waitingline_passport
#                                 passportcontrol hold                 scheduled for   3619.187
#   3543.279 passenger.58         current
#                                 passenger.58                         enter waitingline_security
#                                 securityscan activate                scheduled for   3543.279
#                                 passenger.58 passivate
#   3543.279 securityscan         current
#                                 passenger.58                         leave waitingline_security
#                                 securityscan hold                    scheduled for   3553.279
#   3547.238 luggagepickup        current
#                                 passenger.56 activate                scheduled for   3547.238
#                                 luggagepickup passivate
#   3547.238 passenger.56         current
#   3547.238 passenger.56         ended
#   3553.279 securityscan         current
#                                 passenger.58 activate                scheduled for   3553.279
#                                 securityscan passivate
#   3553.279 passenger.58         current
#                                 passenger.58 hold                    scheduled for   3591.816
#   3580.416 passenger.57         current
#                                 passenger.57                         enter waitingline_passengerLuggagePickup
#                                 luggagepickup activate               scheduled for   3580.416
#                                 passenger.57 passivate
#   3580.416 luggagepickup        current
#                                 passenger.57                         leave waitingline_passengerLuggagePickup
#                                 luggage.57                           leave waitingline_luggageLuggagePickup
#                                 luggagepickup hold                   scheduled for   3610.255
#   3591.816 passenger.58         current
#                                 luggage.58 create
#                                 luggage.58 activate                  scheduled for   3591.816 @process
#                                 passenger.58 hold                    scheduled for   3663.816
#   3591.816 luggage.58           current
#                                 luggage.58 hold                      scheduled for   3606.216
#   3600.000 main                 current
#
# Statistics of waitingline_passport at      3600.000
#                                                                      all    excl.zero         zero
# -------------------------------------------- -------------- ------------ ------------ ------------
# Length of waitingline_passport               duration           3600.000      465.513     3134.487
#                                              mean                  0.129        1.000
#                                              std.deviation         0.336        0.000
#
#                                              minimum               0.000        1.000
#                                              median                0.000        1.000
#                                              90% percentile        1.000        1.000
#                                              95% percentile        1.000        1.000
#                                              maximum               1.000        1.000
#
# Length of stay in waitingline_passport       entries                  60           32           28
#                                              mean                  7.759       14.547
#                                              std.deviation        10.419       10.237
#
#                                              minimum               0.000        0.182
#                                              median                2.158       13.367
#                                              90% percentile       22.919       25.493
#                                              95% percentile       25.842       32.715
#                                              maximum              41.614       41.614
# Statistics of waitingline_security at      3600.000
#                                                                      all    excl.zero         zero
# -------------------------------------------- -------------- ------------ ------------ ------------
# Length of waitingline_security               duration           3600.000        0.000     3600.000
#                                              mean                  0.000          nan
#                                              std.deviation         0.000          nan
#
#                                              minimum               0.000          nan
#                                              median                0.000          nan
#                                              90% percentile        0.000          nan
#                                              95% percentile        0.000          nan
#                                              maximum               0.000          nan
#
# Length of stay in waitingline_security       entries                  59            0           59
#                                              mean                  0.000          nan
#                                              std.deviation         0.000          nan
#
#                                              minimum               0.000          nan
#                                              median                0.000          nan
#                                              90% percentile        0.000          nan
#                                              95% percentile        0.000          nan
#                                              maximum               0.000          nan
# Statistics of waitingline_patdown at      3600.000
#                                                                      all    excl.zero         zero
# -------------------------------------------- -------------- ------------ ------------ ------------
# Length of waitingline_patdown                duration           3600.000        0.000     3600.000
#                                              mean                  0.000          nan
#                                              std.deviation         0.000          nan
#
#                                              minimum               0.000          nan
#                                              median                0.000          nan
#                                              90% percentile        0.000          nan
#                                              95% percentile        0.000          nan
#                                              maximum               0.000          nan
#
# Length of stay in waitingline_patdown        entries                   5            0            5
#                                              mean                  0.000          nan
#                                              std.deviation         0.000          nan
#
#                                              minimum               0.000          nan
#                                              median                0.000          nan
#                                              90% percentile        0.000          nan
#                                              95% percentile        0.000          nan
#                                              maximum               0.000          nan
# Statistics of waitingline_luggage at      3600.000
#                                                                      all    excl.zero         zero
# -------------------------------------------- -------------- ------------ ------------ ------------
# Length of waitingline_luggage                duration           3600.000     3424.487      175.513
#                                              mean                  1.409        1.482
#                                              std.deviation         0.605        0.527
#
#                                              minimum               0.000        1.000
#                                              median                1.000        1.000
#                                              90% percentile        2.000        2.000
#                                              95% percentile        2.000        2.000
#                                              maximum               3.000        3.000
#
# Length of stay in waitingline_luggage        entries                  57           57            0
#                                              mean                 87.661       87.661
#                                              std.deviation         8.369        8.369
#
#                                              minimum              77.617       77.617
#                                              median               86.602       86.602
#                                              90% percentile       95.612       95.612
#                                              95% percentile      104.636      104.636
#                                              maximum             113.828      113.828

# %% [markdown]
# ## Working 18/09/2017

# %%
import salabim as sim
import time
import sys

class PassengerGenerator(sim.Component):
    def process(self):
        while True:
            Passenger()
            yield self.hold(sim.Normal(60).sample())

class Passenger(sim.Component):
    def process(self):
        # Passport control
        self.enter(waitingline_passport)
        if passportcontrol.ispassive():
            passportcontrol.activate()
        yield self.passivate()

        # Walking from passport control to security scan
        yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s

        # Security Scan
        self.enter(waitingline_security)
        if securityscan.ispassive():
            securityscan.activate()
        yield self.passivate()

        # Put luggage on belt
        yield self.hold(sim.Uniform(20,40).sample())
        Luggage(self.name())

        # 10% Pat Down Requirement
        if (sim.Uniform(1,100).sample() <= 10):
            # Walking from security scan to patdown
            yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
            # Patdown
            self.enter(waitingline_patdown)
            if patdown.ispassive():
                patdown.activate()
            yield self.passivate()

        # Walking along luggage belt
        yield self.hold(10/(0.5*1000/(60*60))) # convert 2.5 km/h to m/s

        # Pick up luggage, not matching owner
        self.enter(waitingline_passengerLuggagePickup)
        if luggagePickup.ispassive():
            luggagePickup.activate()
        yield self.passivate()


class Luggage(sim.Component):
    def __init__(self, passengerName, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.owner = passengerName

    def process(self):
        # Roll along luggage belt
        yield self.hold(10/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s

        # Enter luggage waiting line
        self.enter(waitingline_luggageLuggagePickup)
        #if luggagePickup.ispassive():
        #        luggagePickup.activate()
        self.passivate()

class PassportControl(sim.Component):
    def process(self):
        while True:
            while len(waitingline_passport) == 0:
                yield self.passivate()
            self.passenger = waitingline_passport.pop()
            yield self.hold(sim.Triangular(30.,90.,45.).sample())
            self.passenger.activate()

class SecurityScan(sim.Component):
    def process(self):
        while True:
            while len(waitingline_security) == 0:
                yield self.passivate()
            self.passenger = waitingline_security.pop()
            yield self.hold(10)
            self.passenger.activate()

class PatDown(sim.Component):
    def process(self):
        while True:
            while len(waitingline_patdown) == 0:
                yield self.passivate()
            self.passenger = waitingline_patdown.pop()
            yield self.hold(10) #TODO not yet defined
            self.passenger.activate()

class LuggagePickup(sim.Component):
    def process(self):
        while True:
            while len(waitingline_passengerLuggagePickup) == 0 or len(waitingline_luggageLuggagePickup) == 0:
                yield self.passivate()

            for passenger in waitingline_passengerLuggagePickup:
                for luggage in waitingline_luggageLuggagePickup:
                    if luggage.owner == passenger.name():
                        #found luggage of owner!
                        waitingline_passengerLuggagePickup.remove(passenger)
                        waitingline_luggageLuggagePickup.remove(luggage)

                        yield self.hold(sim.Uniform(20,40).sample())

                        passenger.activate()
                        #luggage.activate() This is problematic because it is never the luggage who activates successfully

                        break

#pax statistics
pax_thru_mean = 0
pax_thru_95 = 0

#queue statistics
passport_length = 0
passport_waiting = 0
luggage_drop_length = 0
luggage_drop_waiting = 0
luggage_pickup_length = 0
luggage_pickup_waiting = 0

#utilization statistics
passport_util = 0
scanner_util = 0
patdown_util = 0

replications = 10
#if len(sys.argv) > 1:
    #replications = int(sys.argv[1])

for exp in range(0,replications):
    #steipatr non-random seed for reproduceability
    env = sim.Environment(trace=False,random_seed=exp)

    PassengerGenerator()
    passportcontrol = PassportControl()
    securityscan = SecurityScan()
    patdown = PatDown()
    luggagePickup = LuggagePickup()

    waitingline_passport = sim.Queue('waitingline_passport')
    waitingline_security = sim.Queue('waitingline_security')
    waitingline_patdown = sim.Queue('waitingline_patdown')
    waitingline_luggage = sim.Queue('waitingline_luggage')

    waitingline_luggageLuggagePickup = sim.Queue('waitingline_luggageLuggagePickup')
    waitingline_passengerLuggagePickup = sim.Queue('waitingline_passengerLuggagePickup')

    # Warm-up - don't collect statistics
    waitingline_passport.length.monitor(False)
    waitingline_security.length.monitor(False)
    waitingline_patdown.length.monitor(False)
    waitingline_luggage.length.monitor(False)
    env.run(duration=60*60)

    # Collect statistics
    waitingline_passport.length.monitor(True)
    waitingline_security.length.monitor(True)
    waitingline_patdown.length.monitor(True)
    waitingline_luggage.length.monitor(True)
    env.run(duration=4*60*60)

    passport_length += waitingline_passport.length.mean()
    passport_waiting += waitingline_passport.length_of_stay.mean()
    luggage_pickup_length += waitingline_luggage.length.mean()
    luggage_pickup_waiting += waitingline_luggage.length_of_stay.mean()

print()
print("-- Pax Statistics --")
print("passenger throughput time mean:")
print("passenger throughput time 95% confidence interval:")
print()
print("-- Queue Statistics --")
print("passport queue length mean:",passport_length/replications)
print("passport queue waiting time mean [s]:",passport_waiting/replications)
print("luggage drop length mean:")
print("luggage drop waiting time mean [s]:")
print("luggage pickup length mean:",luggage_pickup_length/replications)
print("luggage pickup waiting time mean [s]:",luggage_pickup_waiting/replications)
print()
print("-- Utilization Statistics --")
print("passport control utilization:")
print("scanner utilization:")
print("patdown utilization:")
print()
# Out:
# -- Pax Statistics --
# passenger throughput time mean:
# passenger throughput time 95% confidence interval:
#
# -- Queue Statistics --
# passport queue length mean: 0.186405712442
# passport queue waiting time mean [s]: 11.1099128857
# luggage drop length mean:
# luggage drop waiting time mean [s]:
# luggage pickup length mean: 0.0
# luggage pickup waiting time mean [s]: nan
#
# -- Utilization Statistics --
# passport control utilization:
# scanner utilization:
# patdown utilization:

# %%
import salabim as sim
import time
import sys

class PassengerGenerator(sim.Component):
    def process(self):
        while True:
            Passenger()
            yield self.hold(sim.Exponential(60).sample())

class Passenger(sim.Component):
    def process(self):
        self.arrivaltime = env.now()
        # Passport control
        self.enter(waitingline_passport)
        if passportControl.ispassive():
            passportControl.activate()
        yield self.passivate()

        # Walking from passport control to security scan
        yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s

        # Security Scan
        self.enter(waitingline_security)
        if securityscan.ispassive():
            securityscan.activate()
        yield self.passivate()

        # Put luggage on belt
        self.enter(waitingline_luggageDropoff)
        if luggageDropoff.ispassive():
            luggageDropoff.activate()
        yield self.passivate()

        # 10% Pat Down Requirement
        if (sim.Uniform(1,100).sample() <= 10):
            # Walking from security scan to patdown
            yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
            # Patdown
            self.enter(waitingline_patdown)
            if patdown.ispassive():
                patdown.activate()
            yield self.passivate()

        # Walking along luggage belt
        yield self.hold(10/(0.5*1000/(60*60))) # convert 2.5 km/h to m/s

        # Pick up luggage, matching owner
        self.enter(waitingline_passengerLuggagePickup)
        if luggagePickup.ispassive():
            luggagePickup.activate()
        yield self.passivate()
        luggagePickup.monitor_time_in_complex.tally(env.now() - self.arrivaltime)


class Luggage(sim.Component):
    def __init__(self, passengerName, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.owner = passengerName

    def process(self):
        # Roll along luggage belt
        yield self.hold(10/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s

        # Enter luggage waiting line
        self.enter(waitingline_luggageLuggagePickup)
        #if luggagePickup.ispassive():
        #        luggagePickup.activate()
        self.passivate()

class PassportControl(sim.Component):
    def process(self):
        while True:
            while len(waitingline_passport) == 0:
                yield self.passivate()
            self.passenger = waitingline_passport.pop()
            yield self.hold(sim.Uniform(20,40).sample())
            self.passenger.activate()

class LuggageDropoff(sim.Component):
    def process(self):
        while True:
            while len(waitingline_luggageDropoff) == 0:
                yield self.passivate()

            self.passenger = waitingline_luggageDropoff.pop()

            Luggage(self.passenger.name())
            yield self.hold(sim.Triangular(30.,90.,45.).sample())
            self.passenger.activate()

class SecurityScan(sim.Component):
    def process(self):
        while True:
            while len(waitingline_security) == 0:
                yield self.passivate()
            self.passenger = waitingline_security.pop()
            yield self.hold(10)
            self.passenger.activate()

class PatDown(sim.Component):
    def process(self):
        while True:
            while len(waitingline_patdown) == 0:
                yield self.passivate()
            self.passenger = waitingline_patdown.pop()
            yield self.hold(sim.Uniform(60,120).sample())
            self.passenger.activate()

class LuggagePickup(sim.Component):
    def __init__(self, *args, **kwargs):
      super().__init__(*args, **kwargs)
      self.monitor_time_in_complex = sim.Monitor(name='time in complex')
  
    def process(self):
        while True:
            while len(waitingline_passengerLuggagePickup) == 0 or len(waitingline_luggageLuggagePickup) == 0:
                yield self.passivate()

            for passenger in waitingline_passengerLuggagePickup:
                #print(passenger.name())
                for luggage in waitingline_luggageLuggagePickup:
                    #print(luggage.name())
                    if luggage.owner == passenger.name():
                        #found luggage of owner!
                        waitingline_passengerLuggagePickup.remove(passenger)
                        waitingline_luggageLuggagePickup.remove(luggage)

                        yield self.hold(sim.Uniform(20,40).sample())

                        passenger.activate()
                        #luggage.activate() This is problematic because it is never the luggage who activates successfully

                        break

            yield self.passivate()

#pax statistics
pax_thru_mean = 0
pax_thru_95 = 0

#queue statistics
passport_length = 0
passport_waiting = 0
luggage_drop_length = 0
luggage_drop_waiting = 0
luggage_pickup_length = 0
luggage_pickup_waiting = 0

#utilization statistics
passport_util = 0
scanner_util = 0
patdown_util = 0

replications = 10
#if len(sys.argv) > 1:
    #replications = int(sys.argv[1])

for exp in range(0,replications):
    #steipatr non-random seed for reproduceability
    env = sim.Environment(trace=False,random_seed=exp)

    PassengerGenerator()
    passportControl = PassportControl()
    luggageDropoff = LuggageDropoff()
    securityscan = SecurityScan()
    patdown = PatDown()
    luggagePickup = LuggagePickup()

    waitingline_passport = sim.Queue('waitingline_passport')
    waitingline_security = sim.Queue('waitingline_security')
    waitingline_patdown = sim.Queue('waitingline_patdown')
    waitingline_luggageDropoff = sim.Queue('waitingline_luggageDropoff')
    waitingline_luggageLuggagePickup = sim.Queue('waitingline_luggageLuggagePickup')
    waitingline_passengerLuggagePickup = sim.Queue('waitingline_passengerLuggagePickup')

    #TODO why suspend only length monitoring? Does everything need to be suspended?
    # Warm-up - don't collect statistics
    waitingline_passport.length.monitor(False)
    waitingline_security.length.monitor(False)
    waitingline_patdown.length.monitor(False)
    waitingline_luggageDropoff.length.monitor(False)
    waitingline_luggageLuggagePickup.length.monitor(False)
    waitingline_passengerLuggagePickup.length.monitor(False)
    env.run(duration=60*60)

    # Collect statistics
    waitingline_passport.length.monitor(True)
    waitingline_security.length.monitor(True)
    waitingline_patdown.length.monitor(True)
    waitingline_luggageDropoff.length.monitor(True)
    waitingline_luggageLuggagePickup.length.monitor(True)
    waitingline_passengerLuggagePickup.length.monitor(True)
    env.run(duration=4*60*60)

    pax_thru_mean += luggagePickup.monitor_time_in_complex.mean()
    pax_thru_95 += luggagePickup.monitor_time_in_complex.percentile(95)
    
    passport_length += waitingline_passport.length.mean()
    passport_waiting += waitingline_passport.length_of_stay.mean()
    luggage_drop_length += waitingline_luggageDropoff.length.mean()
    luggage_drop_waiting += waitingline_luggageDropoff.length_of_stay.mean()
    luggage_pickup_length += waitingline_passengerLuggagePickup.length.mean()
    luggage_pickup_waiting += waitingline_passengerLuggagePickup.length_of_stay.mean()
    

print()
print("-- Pax Statistics --")
print("passenger throughput time mean [s]:",pax_thru_mean/replications, "seconds")
#TODO why not use pax_thru_95 here?
print("passenger throughput time 95% confidence interval [s]:",luggagePickup.monitor_time_in_complex.percentile(95)/replications)
print()
print("-- Queue Statistics --")
print("passport queue length mean:",passport_length/replications)
print("passport queue waiting time mean [s]:",passport_waiting/replications)
print("luggage drop length mean:",luggage_drop_length/replications)
print("luggage drop waiting time mean [s]:",luggage_drop_waiting/replications)
print("luggage pickup length mean:",luggage_pickup_length/replications)
print("luggage pickup waiting time mean [s]:",luggage_pickup_waiting/replications)
print()
print("-- Utilization Statistics --")
print("passport control utilization:")
print("scanner utilization:")
print("patdown utilization:")
print()
# Out:
# -- Pax Statistics --
# passenger throughput time mean [s]: 417.366284822 seconds
# passenger throughput time 95% confidence interval [s]: 53.7432329358
#
# -- Queue Statistics --
# passport queue length mean: 0.262186265975
# passport queue waiting time mean [s]: 14.9198601148
# luggage drop length mean: 3.44650621456
# luggage drop waiting time mean [s]: 176.145579795
# luggage pickup length mean: 0.644492732735
# luggage pickup waiting time mean [s]: 14.1317183642
#
# -- Utilization Statistics --
# passport control utilization:
# scanner utilization:
# patdown utilization:

# %%
60+45+7.2*2++10+45+0.9*14.4+0.1*90+45
# Out:
# 241.36

# %%
#edited by steipatr at 15:23
import salabim as sim
import time, sys

class PassengerGenerator(sim.Component):
    def process(self):
        while True:
            Passenger()
            yield self.hold(sim.Exponential(60).sample())

class Passenger(sim.Component):
    def process(self):
        self.arrivaltime = env.now()
        # Passport control
        self.enter(waitingline_passport)
        if passportControl.ispassive():
            passportControl.activate()
        yield self.passivate()

        # Walking from passport control to luggage belt
        yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s

        # Put luggage on belt
        self.enter(waitingline_luggageDropoff)
        if luggageDropoff.ispassive():
            luggageDropoff.activate()
        yield self.passivate()
        
        # Walking from luggage belt to security scan
        yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
        
        # Security scan
        self.enter(waitingline_security)
        if securityScan.ispassive():
            securityScan.activate()
        yield self.passivate()
        
        # 10% Pat Down Requirement
        if (sim.Uniform(1,100).sample() <= 10):
            # Walking from security scan to patdown
            yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
            # Patdown
            self.enter(waitingline_patdown)
            if patDown.ispassive():
                patDown.activate()
            yield self.passivate()

        # Walking along luggage belt
        yield self.hold(10/(0.5*1000/(60*60))) # convert 2.5 km/h to m/s

        # Pick up luggage, matching owner
        self.enter(waitingline_passengerLuggagePickup)
        if luggagePickup.ispassive():
            luggagePickup.activate()
        yield self.passivate()
        luggagePickup.monitor_time_in_complex.tally(env.now() - self.arrivaltime)
        yield self.hold(sim.Uniform(20,40).sample())
        #waitingline_luggageLuggagePickup.pop()
        #waitingline_luggagePassengerPickup.pop()

class Luggage(sim.Component):
    def __init__(self, passengerName, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.owner = passengerName

    def process(self):
        # Roll along luggage belt
        yield self.hold(20) # 0.5 m/s along 10m belt

        # Enter luggage waiting line
        self.enter(waitingline_luggageLuggagePickup)
        #if luggagePickup.ispassive():
        #        luggagePickup.activate()
        self.passivate()

class Server(sim.Component):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.activeTime = 0
        self.startProcessTime = -1

    def startUtilTime(self):
        self.startProcessTime = env.now()

    def endUtilTime(self):
        if self.startProcessTime >= 0:
            endNow = env.now()
            self.activeTime += endNow - self.startProcessTime
            self.startProcessTime = -1

    def getUtilization(self):
        return self.activeTime / (env.now() - self._creation_time)

class PassportControl(Server):
    def process(self):
        while True:
            while len(waitingline_passport) == 0:
                self.endUtilTime()
                yield self.passivate()

            self.startUtilTime()
            self.passenger = waitingline_passport.pop()
            yield self.hold(sim.Triangular(30.,90.,45.).sample())
            self.passenger.activate()

class LuggageDropoff(Server):
    def process(self):
        while True:
            while len(waitingline_luggageDropoff) == 0:
                yield self.passivate()

            self.passenger = waitingline_luggageDropoff.pop()

            Luggage(self.passenger.name())
            yield self.hold(sim.Uniform(20,40).sample())
            self.passenger.activate()

class SecurityScan(Server):
    def process(self):
        while True:
            while len(waitingline_security) == 0:
                self.endUtilTime()
                yield self.passivate()

            self.startUtilTime()
            self.passenger = waitingline_security.pop()
            yield self.hold(10)
            self.passenger.activate()

class PatDown(Server):
    def process(self):
        while True:
            while len(waitingline_patdown) == 0:
                self.endUtilTime()
                yield self.passivate()

            self.startUtilTime()
            self.passenger = waitingline_patdown.pop()
            yield self.hold(sim.Uniform(60,120).sample())
            self.passenger.activate()

class LuggagePickup(Server):
    def __init__(self, *args, **kwargs):
      super().__init__(*args, **kwargs)
      self.monitor_time_in_complex = sim.Monitor(name='time in complex')

    def process(self):
        noMatches = False

        while True:
            while len(waitingline_passengerLuggagePickup) == 0 or len(waitingline_luggageLuggagePickup) == 0 or noMatches:
                yield self.passivate()

            for passenger in waitingline_passengerLuggagePickup:
                #print(passenger.name())
                for luggage in waitingline_luggageLuggagePickup:
                    #print(luggage.name())
                    if luggage.owner == passenger.name():
                        #found luggage of owner!
                        waitingline_passengerLuggagePickup.remove(passenger)
                        waitingline_luggageLuggagePickup.remove(luggage)
                        yield self.hold(sim.Uniform(20,40).sample())
                        passenger.activate()
                        #luggage.activate() This is problematic because it is never the luggage who activates successfully

                        break

                        
                        
            noMatches = True

def avg(lst):
    return sum(lst)/len(lst)
            
#pax statistics
pax_thru_mean = 0
pax_thru_95 = 0

#queue statistics
passport_length = 0
passport_waiting = 0
luggage_drop_length = 0
luggage_drop_waiting = 0
luggage_pickup_length = 0
luggage_pickup_waiting = 0

#utilization statistics
passport_util = 0
scanner_util = 0
patdown_util = 0

replications = 10
#if len(sys.argv) > 1:
#    replications = int(sys.argv[1])

for exp in range(0,replications):
    #steipatr non-random seed for reproduceability
    env = sim.Environment(trace=False,random_seed=exp)

    PassengerGenerator()
    passportControl = PassportControl()
    luggageDropoff = LuggageDropoff()
    securityScan = SecurityScan()
    patDown = PatDown()
    luggagePickup = LuggagePickup()

    waitingline_passport = sim.Queue('waitingline_passport')
    waitingline_security = sim.Queue('waitingline_security')
    waitingline_patdown = sim.Queue('waitingline_patdown')
    waitingline_luggageDropoff = sim.Queue('waitingline_luggageDropoff')
    waitingline_luggageLuggagePickup = sim.Queue('waitingline_luggageLuggagePickup')
    waitingline_passengerLuggagePickup = sim.Queue('waitingline_passengerLuggagePickup')

    #TODO why suspend only length monitoring? Does everything need to be suspended?
    # Warm-up - don't collect statistics
    waitingline_passport.length.monitor(False)
    waitingline_security.length.monitor(False)
    waitingline_patdown.length.monitor(False)
    waitingline_luggageDropoff.length.monitor(False)
    waitingline_luggageLuggagePickup.length.monitor(False)
    waitingline_passengerLuggagePickup.length.monitor(False)
    env.run(duration=60*60)

    # Collect statistics
    waitingline_passport.length.monitor(True)
    waitingline_security.length.monitor(True)
    waitingline_patdown.length.monitor(True)
    waitingline_luggageDropoff.length.monitor(True)
    waitingline_luggageLuggagePickup.length.monitor(True)
    waitingline_passengerLuggagePickup.length.monitor(True)
    env.run(duration=4*60*60)
    
    print('sum',pax_thru_mean)
    print('mean',luggagePickup.monitor_time_in_complex.mean())
    pax_thru_mean += luggagePickup.monitor_time_in_complex.mean()
    pax_thru_95 += luggagePickup.monitor_time_in_complex.percentile(95)

    passport_length += waitingline_passport.length.mean()
    passport_waiting += waitingline_passport.length_of_stay.mean()
    luggage_drop_length += waitingline_luggageDropoff.length.mean()
    luggage_drop_waiting += waitingline_luggageDropoff.length_of_stay.mean()
    luggage_pickup_length += waitingline_passengerLuggagePickup.length.mean()
    luggage_pickup_waiting += waitingline_passengerLuggagePickup.length_of_stay.mean()

print()
print("-- Pax Statistics --")
print("passenger throughput time mean [s]:", pax_thru_mean) #luggagePickup.monitor_time_in_complex.mean()) #pax_thru_mean/replications
#TODO why not use pax_thru_95 here?
print("passenger throughput time 95% confidence interval [s]:",luggagePickup.monitor_time_in_complex.percentile(95)/replications)
print()
print("-- Queue Statistics --")
print("passport queue length mean:",passport_length/replications)
print("passport queue waiting time mean [s]:",passport_waiting/replications)
print("luggage drop length mean:",luggage_drop_length/replications)
print("luggage drop waiting time mean [s]:",luggage_drop_waiting/replications)
print("luggage pickup length mean:",luggage_pickup_length/replications)
print("luggage pickup waiting time mean [s]:",luggage_pickup_waiting/replications)
print()
print("-- Utilization Statistics --")
print("passport control utilization:",passportControl.getUtilization())
print("scanner utilization:",securityScan.getUtilization())
print("patdown utilization:",patDown.getUtilization())
print()
# Out:
# sum 0
# mean nan
# sum nan
# mean 224.920413738
# sum nan
# mean nan
# sum nan
# mean 202.158002083
# sum nan
# mean 186.191327088
# sum nan
# mean 217.058016689
# sum nan
# mean nan
# sum nan
# mean 210.729422541
# sum nan
# mean 237.869477917
# sum nan
# mean 204.36143001
#
# -- Pax Statistics --
# passenger throughput time mean [s]: nan
# passenger throughput time 95% confidence interval [s]: 20.436143001
#
# -- Queue Statistics --
# passport queue length mean: 3.78590955797
# passport queue waiting time mean [s]: 207.834939289
# luggage drop length mean: 0.000876562861621
# luggage drop waiting time mean [s]: 0.052364568861
# luggage pickup length mean: 167.140965895
# luggage pickup waiting time mean [s]: nan
#
# -- Utilization Statistics --
# passport control utilization: 0.08102153420255453
# scanner utilization: 0.1638888888888889
# patdown utilization: 0.16344041578190602

# %%
print(pax_thru_mean)
print(replications)
print(pax_thru_95)
a=[3,45,5,123,4,5]
avg(a)
# Out:
# nan
# 10
# nan
# 30.833333333333332

# %%
luggagePickup.monitor_time_in_complex.mean()
# Out:
# 204.36143001008739

# %%
monitor_time_in_complex
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-539caa5f90a4> in <module>()
# ----> 1 monitor_time_in_complex
#
# NameError: name 'monitor_time_in_complex' is not defined

# %%
LuggagePickup
# Out:
# __main__.LuggagePickup

# %%
luggagePickup.monitor_time_in_complex

# %%
#edited by steipatr at 15:23
import salabim as sim
import time, sys

class PassengerGenerator(sim.Component):
    def process(self):
        while True:
            Passenger()
            yield self.hold(sim.Exponential(60).sample())

class Passenger(sim.Component):
    def process(self):
        self.arrivaltime = env.now()
        # Passport control
        self.enter(waitingline_passport)
        if passportControl.ispassive():
            passportControl.activate()
        yield self.passivate()

        # Walking from passport control to luggage belt
        yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s

        # Put luggage on belt
        self.enter(waitingline_luggageDropoff)
        if luggageDropoff.ispassive():
            luggageDropoff.activate()
        yield self.passivate()
        
        # Walking from luggage belt to security scan
        yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
        
        # Security scan
        self.enter(waitingline_security)
        if securityScan.ispassive():
            securityScan.activate()
        yield self.passivate()
        
        # 10% Pat Down Requirement
        if (sim.Uniform(1,100).sample() <= 10):
            # Walking from security scan to patdown
            yield self.hold(5/(2.5*1000/(60*60))) # convert 2.5 km/h to m/s
            # Patdown
            self.enter(waitingline_patdown)
            if patDown.ispassive():
                patDown.activate()
            yield self.passivate()

        # Walking along luggage belt
        yield self.hold(10/(0.5*1000/(60*60))) # convert 2.5 km/h to m/s

        # Pick up luggage, matching owner
        self.enter(waitingline_passengerLuggagePickup)
        if luggagePickup.ispassive():
            luggagePickup.activate()
        yield self.passivate()
        luggagePickup.monitor_time_in_complex.tally(env.now() - self.arrivaltime)
        yield self.hold(sim.Uniform(20,40).sample())
        #waitingline_luggageLuggagePickup.pop()
        #waitingline_luggagePassengerPickup.pop()

class Luggage(sim.Component):
    def __init__(self, passengerName, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.owner = passengerName

    def process(self):
        # Roll along luggage belt
        yield self.hold(20) # 0.5 m/s along 10m belt

        # Enter luggage waiting line
        self.enter(waitingline_luggageLuggagePickup)
        #if luggagePickup.ispassive():
        #        luggagePickup.activate()
        self.passivate()

class Server(sim.Component):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.activeTime = 0
        self.startProcessTime = -1

    def startUtilTime(self):
        self.startProcessTime = env.now()

    def endUtilTime(self):
        if self.startProcessTime >= 0:
            endNow = env.now()
            self.activeTime += endNow - self.startProcessTime
            self.startProcessTime = -1

    def getUtilization(self):
        return self.activeTime / (env.now() - self._creation_time)

class PassportControl(Server):
    def process(self):
        while True:
            while len(waitingline_passport) == 0:
                self.endUtilTime()
                yield self.passivate()

            self.startUtilTime()
            self.passenger = waitingline_passport.pop()
            yield self.hold(sim.Triangular(30.,90.,45.).sample())
            self.passenger.activate()

class LuggageDropoff(Server):
    def process(self):
        while True:
            while len(waitingline_luggageDropoff) == 0:
                yield self.passivate()

            self.passenger = waitingline_luggageDropoff.pop()

            Luggage(self.passenger.name())
            yield self.hold(sim.Uniform(20,40).sample())
            self.passenger.activate()

class SecurityScan(Server):
    def process(self):
        while True:
            while len(waitingline_security) == 0:
                self.endUtilTime()
                yield self.passivate()

            self.startUtilTime()
            self.passenger = waitingline_security.pop()
            yield self.hold(10)
            self.passenger.activate()

class PatDown(Server):
    def process(self):
        while True:
            while len(waitingline_patdown) == 0:
                self.endUtilTime()
                yield self.passivate()

            self.startUtilTime()
            self.passenger = waitingline_patdown.pop()
            yield self.hold(sim.Uniform(60,120).sample())
            self.passenger.activate()

class LuggagePickup(Server):
    def __init__(self, *args, **kwargs):
      super().__init__(*args, **kwargs)
      self.monitor_time_in_complex = sim.Monitor(name='time in complex')

    def process(self):
        noMatches = False

        while True:
            while len(waitingline_passengerLuggagePickup) == 0 or len(waitingline_luggageLuggagePickup) == 0 or noMatches:
                yield self.passivate()

            for passenger in waitingline_passengerLuggagePickup:
                #print(passenger.name())
                for luggage in waitingline_luggageLuggagePickup:
                    #print(luggage.name())
                    if luggage.owner == passenger.name():
                        #found luggage of owner!
                        waitingline_passengerLuggagePickup.remove(passenger)
                        waitingline_luggageLuggagePickup.remove(luggage)
                        yield self.hold(sim.Uniform(20,40).sample())
                        passenger.activate()
                        #luggage.activate() This is problematic because it is never the luggage who activates successfully

                        break

                        
                        
            noMatches = True

def avg(lst):
    cleanedlst = [x for x in lst if str(x) != 'nan']
    if len(cleanedlst)==0:
        return 0
    return sum(cleanedlst)/len(cleanedlst)
            
#pax statistics
pax_thru_mean = []
pax_thru_95 = []

#queue statistics
passport_length = 0
passport_waiting = 0
luggage_drop_length = 0
luggage_drop_waiting = 0
luggage_pickup_length = 0
luggage_pickup_waiting = 0

#utilization statistics
passport_util = 0
scanner_util = 0
patdown_util = 0

replications = 10
#if len(sys.argv) > 1:
#    replications = int(sys.argv[1])

for exp in range(0,replications):
    #steipatr non-random seed for reproduceability
    env = sim.Environment(trace=False,random_seed=exp)

    PassengerGenerator()
    passportControl = PassportControl()
    luggageDropoff = LuggageDropoff()
    securityScan = SecurityScan()
    patDown = PatDown()
    luggagePickup = LuggagePickup()

    waitingline_passport = sim.Queue('waitingline_passport')
    waitingline_security = sim.Queue('waitingline_security')
    waitingline_patdown = sim.Queue('waitingline_patdown')
    waitingline_luggageDropoff = sim.Queue('waitingline_luggageDropoff')
    waitingline_luggageLuggagePickup = sim.Queue('waitingline_luggageLuggagePickup')
    waitingline_passengerLuggagePickup = sim.Queue('waitingline_passengerLuggagePickup')

    #TODO why suspend only length monitoring? Does everything need to be suspended?
    # Warm-up - don't collect statistics
    waitingline_passport.length.monitor(False)
    waitingline_security.length.monitor(False)
    waitingline_patdown.length.monitor(False)
    waitingline_luggageDropoff.length.monitor(False)
    waitingline_luggageLuggagePickup.length.monitor(False)
    waitingline_passengerLuggagePickup.length.monitor(False)
    env.run(duration=60*60)

    # Collect statistics
    waitingline_passport.length.monitor(True)
    waitingline_security.length.monitor(True)
    waitingline_patdown.length.monitor(True)
    waitingline_luggageDropoff.length.monitor(True)
    waitingline_luggageLuggagePickup.length.monitor(True)
    waitingline_passengerLuggagePickup.length.monitor(True)
    env.run(duration=4*60*60)
    
    #print('list',pax_thru_mean)
    #print('mean',luggagePickup.monitor_time_in_complex.mean())
    #print('avglst',avg(pax_thru_mean))
    #print('95percentile',pax_thru_95)
    pax_thru_mean += [luggagePickup.monitor_time_in_complex.mean()]
    pax_thru_95 += [luggagePickup.monitor_time_in_complex.percentile(95)]

    passport_length += waitingline_passport.length.mean()
    passport_waiting += waitingline_passport.length_of_stay.mean()
    luggage_drop_length += waitingline_luggageDropoff.length.mean()
    luggage_drop_waiting += waitingline_luggageDropoff.length_of_stay.mean()
    luggage_pickup_length += waitingline_passengerLuggagePickup.length.mean()
    luggage_pickup_waiting += waitingline_passengerLuggagePickup.length_of_stay.mean()

print()
print("-- Pax Statistics --")
print("passenger throughput time mean [s]:", avg(pax_thru_mean)) #luggagePickup.monitor_time_in_complex.mean()) #pax_thru_mean/replications
#TODO why not use pax_thru_95 here?
print("passenger throughput time 95% confidence interval [s]:", avg(pax_thru_95))#luggagePickup.monitor_time_in_complex.percentile(95)/replications)
print()
print("-- Queue Statistics --")
print("passport queue length mean:",passport_length/replications)
print("passport queue waiting time mean [s]:",passport_waiting/replications)
print("luggage drop length mean:",luggage_drop_length/replications)
print("luggage drop waiting time mean [s]:",luggage_drop_waiting/replications)
print("luggage pickup length mean:",luggage_pickup_length/replications)
print("luggage pickup waiting time mean [s]:",luggage_pickup_waiting/replications)
print()
print("-- Utilization Statistics --")
print("passport control utilization:",passportControl.getUtilization())
print("scanner utilization:",securityScan.getUtilization())
print("patdown utilization:",patDown.getUtilization())
print()
# Out:
# avglst 0
# 95percentile []
# avglst 0
# 95percentile [nan]
# avglst 224.920413738
# 95percentile [nan, 224.92041373811875]
# avglst 224.920413738
# 95percentile [nan, 224.92041373811875, nan]
# avglst 213.539207911
# 95percentile [nan, 224.92041373811875, nan, 202.15800208325837]
# avglst 204.423247636
# 95percentile [nan, 224.92041373811875, nan, 202.15800208325837, 186.19132708801803]
# avglst 207.5819399
# 95percentile [nan, 224.92041373811875, nan, 202.15800208325837, 186.19132708801803, 217.05801668941922]
# avglst 207.5819399
# 95percentile [nan, 224.92041373811875, nan, 202.15800208325837, 186.19132708801803, 217.05801668941922, nan]
# avglst 208.211436428
# 95percentile [nan, 224.92041373811875, nan, 202.15800208325837, 186.19132708801803, 217.05801668941922, nan, 210.72942254064509]
# avglst 213.154443343
# 95percentile [nan, 224.92041373811875, nan, 202.15800208325837, 186.19132708801803, 217.05801668941922, nan, 210.72942254064509, 237.86947791688056]
#
# -- Pax Statistics --
# passenger throughput time mean [s]: 211.898298581
# passenger throughput time 95% confidence interval [s]: 211.898298581
#
# -- Queue Statistics --
# passport queue length mean: 3.78590955797
# passport queue waiting time mean [s]: 207.834939289
# luggage drop length mean: 0.000876562861621
# luggage drop waiting time mean [s]: 0.052364568861
# luggage pickup length mean: 167.140965895
# luggage pickup waiting time mean [s]: nan
#
# -- Utilization Statistics --
# passport control utilization: 0.08102153420255453
# scanner utilization: 0.1638888888888889
# patdown utilization: 0.16344041578190602
